# %%
# !pip install openpyxl  --quiet

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from collections import defaultdict
import string
import tensorflow as tf
import re
import os
import time
from tensorflow import keras
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split

# %%
ENCODER_LEN = 100
DECODER_LEN = 20
BATCH_SIZE = 64
BUFFER_SIZE = BATCH_SIZE*8

# %%
duc=pd.read_excel("/content/drive/MyDrive/Copy of duc_2004.xlsx",engine = 'openpyxl')

# %%
duc.head()
# Out:
#                                                 text  \
# 0  cambodian leader hun sen on friday rejected op...
# 1  king norodom sihanouk has declined requests to...
# 2  cambodia 's two-party opposition asked the asi...
# 3  cambodia 's ruling party responded tuesday to ...
# 4  cambodia 's leading opposition party ruled out...
#
#                                             summary1  \
# 0  Cambodian government rejects opposition's call...
# 1  Sihanouk refuses to chair Cambodian political ...
# 2  Opposition asks end to loans to "illegal" Camb...
# 3  Cambodian party defends leader Hun Sen against...
# 4  Cambodian party rejects government offer to sh...
#
#                                             summary2  \
# 0  Cambodian leader Hun Sen rejects opposition de...
# 1  Sihanouk refuses to host talks of Cambodian po...
# 2  Cambodian opposition asks ADB to stop loans to...
# 3  CPP defends Hun Sen to US Senate. Asks rejecti...
# 4  FUNCINPEC refuses to share presidency with CPP...
#
#                                             summary3  \
# 0  Hun Sen rejects out of country talks, Sihanouk...
# 1  Efforts to form a government deadlocked, Sihan...
# 2  Cambodia's two-party opposition seeks to block...
# 3  Cambodia's ruling party seeks to counter human...
# 4  Disputes over presidency block efforts to form...
#
#                                             summary4
# 0  New Cambodian government in limbo as Hun Sen r...
# 1  Norodom Sihanouk declines role to mediate in C...
# 2  Opponents of Cambodian government ask Asian De...
# 3  US House seeks probe of Cambodian rights viola...
# 4  Opposition Royalists reject power sharing and ...

# %%
news = pd.read_excel("/content/drive/MyDrive/Copy of inshorts.xlsx",engine = 'openpyxl')
news.drop(['Source ', 'Time ', 'Publish Date'], axis=1, inplace=True)
news.head()
print(f'Dataset size: {len(news)}')
# Out:
# Dataset size: 55104

# %%
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer

# Load the DUC dataset
df_2 = duc.copy()  # Make a copy of the DataFrame to avoid modifying the original
# Initialize the embedding model (using Sentence Transformers)
model = SentenceTransformer('all-MiniLM-L6-v2')

# Preprocess the dataset (keeping the relevant text and summaries)
# Assuming the dataset has columns: 'text', 'summary1', 'summary2', 'summary3', 'summary4'
texts = df_2['text'].tolist()
summaries = df_2[['summary1', 'summary2', 'summary3', 'summary4']].values

# Encode texts and summaries
text_embeddings = model.encode(texts, convert_to_tensor=True)
summary_embeddings = [model.encode([summaries[i][j] for j in range(4)], convert_to_tensor=True) for i in range(len(summaries))]

# Find the summary with the highest similarity for each text
best_summaries = []
for i, text_embedding in enumerate(text_embeddings):
    # Calculate cosine similarities between the text and each summary
    similarities = cosine_similarity([text_embedding.cpu().numpy()], [summary.cpu().numpy() for summary in summary_embeddings[i]])

    # Get the index of the summary with the highest similarity
    best_summary_index = similarities.argmax()
    best_summaries.append(summaries[i][best_summary_index])

# Add the best summary to the dataframe and drop other summary columns
df_2['best_summary'] = best_summaries
df_2 = df_2[['text', 'best_summary']]  # Keep only the text and the best summary

# Save the processed dataset
df_2.to_csv("processed_duc_dataset.csv", index=False)

print("Processed dataset saved with the best summary for each text!")
# Out:
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Processed dataset saved with the best summary for each text!

# %%
duc = pd.read_csv("/content/processed_duc_dataset.csv")
duc.head()
# Out:
#                                                 text  \
# 0  cambodian leader hun sen on friday rejected op...
# 1  king norodom sihanouk has declined requests to...
# 2  cambodia 's two-party opposition asked the asi...
# 3  cambodia 's ruling party responded tuesday to ...
# 4  cambodia 's leading opposition party ruled out...
#
#                                         best_summary
# 0  Cambodian leader Hun Sen rejects opposition de...
# 1  Sihanouk refuses to chair Cambodian political ...
# 2  Opponents of Cambodian government ask Asian De...
# 3  Cambodian party defends leader Hun Sen against...
# 4  Cambodian party rejects government offer to sh...

# %%
# duc_columns = duc.columns.tolist()
# duc_columns.remove('text')
# duc_columns.remove('summary1')
# duc.drop(duc_columns, axis='columns', inplace=True)

# %%
duc
# Out:
#                                                   text  \
# 0    cambodian leader hun sen on friday rejected op...
# 1    king norodom sihanouk has declined requests to...
# 2    cambodia 's two-party opposition asked the asi...
# 3    cambodia 's ruling party responded tuesday to ...
# 4    cambodia 's leading opposition party ruled out...
# ..                                                 ...
# 495  german foreign minister joschka fischer , who ...
# 496  the trials of three outspoken dissidents over ...
# 497  his friend and political mentor is jailed , ro...
# 498  by sentencing two of the country 's most promi...
# 499  six months after president clinton traveled to...
#
#                                           best_summary
# 0    Cambodian leader Hun Sen rejects opposition de...
# 1    Sihanouk refuses to chair Cambodian political ...
# 2    Opponents of Cambodian government ask Asian De...
# 3    Cambodian party defends leader Hun Sen against...
# 4    Cambodian party rejects government offer to sh...
# ..                                                 ...
# 495  German Foreign Minister calls China's sentenci...
# 496  China renews crackdown on political activists;...
# 497  China Democracy Party, Zha, legally subversive...
# 498  China: two pro-democracy politicians given lon...
# 499  Clinton, China policy, Jiang, Xu, Wang, Qin, h...
#
# [500 rows x 2 columns]

# %%
duc.rename(columns = { 'best_summary':'Headline','text':'Short'}, inplace = True)

# %%
duc
# Out:
#                                                  Short  \
# 0    cambodian leader hun sen on friday rejected op...
# 1    king norodom sihanouk has declined requests to...
# 2    cambodia 's two-party opposition asked the asi...
# 3    cambodia 's ruling party responded tuesday to ...
# 4    cambodia 's leading opposition party ruled out...
# ..                                                 ...
# 495  german foreign minister joschka fischer , who ...
# 496  the trials of three outspoken dissidents over ...
# 497  his friend and political mentor is jailed , ro...
# 498  by sentencing two of the country 's most promi...
# 499  six months after president clinton traveled to...
#
#                                               Headline
# 0    Cambodian leader Hun Sen rejects opposition de...
# 1    Sihanouk refuses to chair Cambodian political ...
# 2    Opponents of Cambodian government ask Asian De...
# 3    Cambodian party defends leader Hun Sen against...
# 4    Cambodian party rejects government offer to sh...
# ..                                                 ...
# 495  German Foreign Minister calls China's sentenci...
# 496  China renews crackdown on political activists;...
# 497  China Democracy Party, Zha, legally subversive...
# 498  China: two pro-democracy politicians given lon...
# 499  Clinton, China policy, Jiang, Xu, Wang, Qin, h...
#
# [500 rows x 2 columns]

# %%
news
# Out:
#                                                 Headline  \
# 0      4 ex-bank officials booked for cheating bank o...
# 1         Supreme Court to go paperless in 6 months: CJI
# 2      At least 3 killed, 30 injured in blast in Sylh...
# 3      Why has Reliance been barred from trading in f...
# 4      Was stopped from entering my own studio at Tim...
# ...                                                  ...
# 55099         Sensex loses 400 points to hit 52-week low
# 55100      China to inject $91 bn into the money markets
# 55101   Ghulam Ali set to make acting debut in Bollywood
# 55102       IS acknowledges death of Jihadi John: Report
# 55103        Cairn to seek $600 mn from India in damages
#
#                                                    Short
# 0      The CBI on Saturday booked four former officia...
# 1      Chief Justice JS Khehar has said the Supreme C...
# 2      At least three people were killed, including a...
# 3      Mukesh Ambani-led Reliance Industries (RIL) wa...
# 4      TV news anchor Arnab Goswami has said he was t...
# ...                                                  ...
# 55099  Tracking weak cues from the Asian markets, the...
# 55100  Amid growing concerns about China&#39;s econom...
# 55101  Pakistani Ghazal singer Ghulam Ali will soon m...
# 55102  The Islamic State (IS) has acknowledged the de...
# 55103  UK-based oil firm Cairn Energy on Tuesday said...
#
# [55104 rows x 2 columns]

# %%
#df = pd.concat([duc, news])
#del df1, df2
# df = pd.concat([duc, news], ignore_index=True, sort=False)
# Shuffling the df
# df = df.sample(frac=1).reset_index(drop=True)

df = news

print(f'Dataset size: {len(df)}')
news=df
# Out:
# Dataset size: 55104

# %%
news.head()
# Out:
#                                             Headline  \
# 0  4 ex-bank officials booked for cheating bank o...
# 1     Supreme Court to go paperless in 6 months: CJI
# 2  At least 3 killed, 30 injured in blast in Sylh...
# 3  Why has Reliance been barred from trading in f...
# 4  Was stopped from entering my own studio at Tim...
#
#                                                Short
# 0  The CBI on Saturday booked four former officia...
# 1  Chief Justice JS Khehar has said the Supreme C...
# 2  At least three people were killed, including a...
# 3  Mukesh Ambani-led Reliance Industries (RIL) wa...
# 4  TV news anchor Arnab Goswami has said he was t...

# %%
news=news.replace(r'&#45;','-', regex=True).replace(r'&#39;','`', regex=True).replace(r'&amp','&', regex=True).replace(r'&#34;','"', regex=True)
news.head()
# Out:
#                                             Headline  \
# 0  4 ex-bank officials booked for cheating bank o...
# 1     Supreme Court to go paperless in 6 months: CJI
# 2  At least 3 killed, 30 injured in blast in Sylh...
# 3  Why has Reliance been barred from trading in f...
# 4  Was stopped from entering my own studio at Tim...
#
#                                                Short
# 0  The CBI on Saturday booked four former officia...
# 1  Chief Justice JS Khehar has said the Supreme C...
# 2  At least three people were killed, including a...
# 3  Mukesh Ambani-led Reliance Industries (RIL) wa...
# 4  TV news anchor Arnab Goswami has said he was t...

# %%
article = news['Short']
summary = news['Headline']

article = article.apply(lambda x: '<SOS> ' + x + ' <EOS>')
summary = summary.apply(lambda x: '<SOS> ' + x + ' <EOS>')

# %%
def preprocess(text):
    text = re.sub(r"&.[1-9]+;"," ",text)
    return text
article = article.apply(lambda x: preprocess(x))
summary = summary.apply(lambda x: preprocess(x))

# %%
article[8]
# Out:
# '<SOS> In an apparent jibe at UP`s anti-Romeo squads, Delhi`s Tourism Minister Kapil Mishra has said both Romeo and Juliet are welcome in Delhi as there would be no Mogambo (a Hindi movie villainous character) to object. He further stated the AAP government is working on improving Delhi`s nightlife. "The nightlife ensures the law and order of a place," he added. <EOS>'

# %%
print("****************************")
summary[8]
# Out:
# ****************************
# '<SOS> Both Romeo and Juliet are welcome in Delhi: AAP Minister <EOS>'

# %%
filters = '!"#$%&()*+,-./:;=?@[\\]^_`{|}~\t\n'
oov_token = '<unk>'
article_tokenizer = tf.keras.preprocessing.text.Tokenizer(oov_token=oov_token)
summary_tokenizer = tf.keras.preprocessing.text.Tokenizer(filters=filters, oov_token=oov_token)
article_tokenizer.fit_on_texts(article)
summary_tokenizer.fit_on_texts(summary)
inputs = article_tokenizer.texts_to_sequences(article)
targets = summary_tokenizer.texts_to_sequences(summary)

# %%
ENCODER_VOCAB = len(article_tokenizer.word_index) + 1
DECODER_VOCAB = len(summary_tokenizer.word_index) + 1
print(ENCODER_VOCAB, DECODER_VOCAB)
# Out:
# 76362 29661

# %%
# Padding ensures that all sequences are of uniform length, which is crucial for training neural networks.
# Casting to int64 ensures that the data type aligns with the expected input for TensorFlow models (some layers or operations might need int64).
inputs = tf.keras.preprocessing.sequence.pad_sequences(inputs, maxlen=ENCODER_LEN, padding='post', truncating='post')
targets = tf.keras.preprocessing.sequence.pad_sequences(targets, maxlen=DECODER_LEN, padding='post', truncating='post')
inputs = tf.cast(inputs, dtype=tf.int64)
targets = tf.cast(targets, dtype=tf.int64)

# %%
dataset = tf.data.Dataset.from_tensor_slices((inputs, targets)).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

# %% [markdown]
# vanilla transformer

# %%
def get_angles(position, i, d_model):
    angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
    return position * angle_rates

def positional_encoding(position, d_model):
    angle_rads = get_angles(
        np.arange(position)[:, np.newaxis],
        np.arange(d_model)[np.newaxis, :],
        d_model
    )

    angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])

    angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])

    pos_encoding = angle_rads[np.newaxis, ...]

    return tf.cast(pos_encoding, dtype=tf.float32)

def create_padding_mask(seq):
    seq = tf.cast(tf.math.equal(seq, 0), tf.float32)
    return seq[:, tf.newaxis, tf.newaxis, :]

def create_look_ahead_mask(size):
    mask = 1 - tf.linalg.band_part(tf.ones((size, size)), -1, 0)
    return mask

def scaled_dot_product_attention(q, k, v, mask):
    matmul_qk = tf.matmul(q, k, transpose_b=True)

    dk = tf.cast(tf.shape(k)[-1], tf.float32)
    scaled_attention_logits = matmul_qk / tf.math.sqrt(dk)

    if mask is not None:
        scaled_attention_logits += (mask * -1e9)

    attention_weights = tf.nn.softmax(scaled_attention_logits, axis=-1)

    output = tf.matmul(attention_weights, v)
    return output, attention_weights

# %%
class MultiHeadAttention(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads):
        super(MultiHeadAttention, self).__init__()
        self.num_heads = num_heads
        self.d_model = d_model

        assert d_model % self.num_heads == 0

        self.depth = d_model // self.num_heads

        self.wq = tf.keras.layers.Dense(d_model)
        self.wk = tf.keras.layers.Dense(d_model)
        self.wv = tf.keras.layers.Dense(d_model)

        self.dense = tf.keras.layers.Dense(d_model)

    def split_heads(self, x, batch_size):
        x = tf.reshape(x, (batch_size, -1, self.num_heads, self.depth))
        return tf.transpose(x, perm=[0, 2, 1, 3])

    def call(self, v, k, q, mask):
        batch_size = tf.shape(q)[0]

        q = self.wq(q)
        k = self.wk(k)
        v = self.wv(v)

        q = self.split_heads(q, batch_size)
        k = self.split_heads(k, batch_size)
        v = self.split_heads(v, batch_size)

        scaled_attention, attention_weights = scaled_dot_product_attention(
            q, k, v, mask)

        scaled_attention = tf.transpose(scaled_attention, perm=[0, 2, 1, 3])

        concat_attention = tf.reshape(scaled_attention, (batch_size, -1, self.d_model))
        output = self.dense(concat_attention)

        return output, attention_weights

def point_wise_feed_forward_network(d_model, dff):
    return tf.keras.Sequential([
        tf.keras.layers.Dense(dff, activation='relu'),
        tf.keras.layers.Dense(d_model)
    ])

# %%
class EncoderLayer(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads, dff, rate=0.1):
        super(EncoderLayer, self).__init__()

        self.mha = MultiHeadAttention(d_model, num_heads)
        self.ffn = point_wise_feed_forward_network(d_model, dff)

        self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)

        self.dropout1 = tf.keras.layers.Dropout(rate)
        self.dropout2 = tf.keras.layers.Dropout(rate)

    def call(self, x, training, mask):
        attn_output, _ = self.mha(x, x, x, mask)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(x + attn_output)

        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output, training=training)
        out2 = self.layernorm2(out1 + ffn_output)

        return out2

# %%
class DecoderLayer(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads, dff, rate=0.1):
        super(DecoderLayer, self).__init__()

        self.mha1 = MultiHeadAttention(d_model, num_heads)
        self.mha2 = MultiHeadAttention(d_model, num_heads)

        self.ffn = point_wise_feed_forward_network(d_model, dff)

        self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm3 = tf.keras.layers.LayerNormalization(epsilon=1e-6)

        self.dropout1 = tf.keras.layers.Dropout(rate)
        self.dropout2 = tf.keras.layers.Dropout(rate)
        self.dropout3 = tf.keras.layers.Dropout(rate)


    def call(self, x, enc_output, training, look_ahead_mask, padding_mask):
        attn1, attn_weights_block1 = self.mha1(x, x, x, look_ahead_mask)
        attn1 = self.dropout1(attn1, training=training)
        out1 = self.layernorm1(attn1 + x)

        attn2, attn_weights_block2 = self.mha2(enc_output, enc_output, out1, padding_mask)
        attn2 = self.dropout2(attn2, training=training)
        out2 = self.layernorm2(attn2 + out1)

        ffn_output = self.ffn(out2)
        ffn_output = self.dropout3(ffn_output, training=training)
        out3 = self.layernorm3(ffn_output + out2)

        return out3, attn_weights_block1, attn_weights_block2

# %%
class Encoder(tf.keras.layers.Layer):
    def __init__(self, num_layers, d_model, num_heads, dff, input_vocab_size, maximum_position_encoding, rate=0.1):
        super(Encoder, self).__init__()

        self.d_model = d_model
        self.num_layers = num_layers

        # Embedding and positional encoding layers
        self.embedding = tf.keras.layers.Embedding(input_vocab_size, d_model)
        self.pos_encoding = positional_encoding(maximum_position_encoding, self.d_model)

        # Encoder layers (list of EncoderLayer instances)
        self.enc_layers = [EncoderLayer(d_model, num_heads, dff, rate) for _ in range(num_layers)]

        self.dropout = tf.keras.layers.Dropout(rate)

    def call(self, x, training, mask):
        seq_len = tf.shape(x)[1]

        # Apply embedding and positional encoding
        x = self.embedding(x)
        x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
        x += self.pos_encoding[:, :seq_len, :]

        x = self.dropout(x, training=training)

        # Pass through each encoder layer
        for i in range(self.num_layers):
            # Make sure mask is passed as keyword argument
            x = self.enc_layers[i](x, training=training, mask=mask)

        return x


class Decoder(tf.keras.layers.Layer):

    def __init__(self, num_layers, d_model, num_heads, dff, target_vocab_size, maximum_position_encoding, rate=0.1):
        super(Decoder, self).__init__()

        self.d_model = d_model
        self.num_layers = num_layers

        # Embedding and positional encoding layers
        self.embedding = tf.keras.layers.Embedding(target_vocab_size, d_model)
        self.pos_encoding = positional_encoding(maximum_position_encoding, d_model)

        # Decoder layers (list of DecoderLayer instances)
        self.dec_layers = [DecoderLayer(d_model, num_heads, dff, rate) for _ in range(num_layers)]
        self.dropout = tf.keras.layers.Dropout(rate)

    def call(self, x, enc_output, training, look_ahead_mask, padding_mask):
        seq_len = tf.shape(x)[1]
        attention_weights = {}

        # Apply embedding and positional encoding
        x = self.embedding(x)
        x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
        x += self.pos_encoding[:, :seq_len, :]

        x = self.dropout(x, training=training)

        # Pass through each decoder layer
        for i in range(self.num_layers):
            # Pass the look_ahead_mask and padding_mask as keyword arguments
            x, block1, block2 = self.dec_layers[i](x, enc_output, training=training, look_ahead_mask=look_ahead_mask, padding_mask=padding_mask)

            # Save the attention weights for later inspection
            attention_weights['decoder_layer{}_block1'.format(i+1)] = block1
            attention_weights['decoder_layer{}_block2'.format(i+1)] = block2

        return x, attention_weights

# %%
class Transformer(tf.keras.Model):
    def __init__(self, num_layers, d_model, num_heads, dff, input_vocab_size, target_vocab_size, pe_input, pe_target, rate=0.1):
        super(Transformer, self).__init__()

        self.encoder = Encoder(num_layers, d_model, num_heads, dff, input_vocab_size, pe_input, rate)
        self.decoder = Decoder(num_layers, d_model, num_heads, dff, target_vocab_size, pe_target, rate)
        self.final_layer = tf.keras.layers.Dense(target_vocab_size)

    def call(self, inp, tar, training, enc_padding_mask, look_ahead_mask, dec_padding_mask):
        # Pass the input through the encoder
        enc_output = self.encoder(x=inp, training=training, mask=enc_padding_mask)

        # Pass the target and encoder output through the decoder
        dec_output, attention_weights = self.decoder(
            x=tar, enc_output=enc_output, training=training,
            look_ahead_mask=look_ahead_mask, padding_mask=dec_padding_mask
        )

        # Pass the decoder output through the final linear layer
        final_output = self.final_layer(dec_output)

        return final_output, attention_weights

# %%
num_layers = 3
d_model = 128
dff = 512
num_heads = 4
dropout_rate = 0.2
EPOCHS = 30

# %% [markdown]
# custom learning rate

# %%
class CustomSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, d_model, warmup_steps=4000):
        super(CustomSchedule, self).__init__()

        self.d_model = d_model
        self.d_model = tf.cast(self.d_model, tf.float32)
        self.warmup_steps = warmup_steps

    def __call__(self, step):
        # Cast step to float32 for compatibility with tf.math.rsqrt
        step = tf.cast(step, tf.float32)
        arg1 = tf.math.rsqrt(step)
        arg2 = step * (self.warmup_steps ** -1.5)

        return tf.math.rsqrt(self.d_model) * tf.math.minimum(arg1, arg2)

# %%
learning_rate = CustomSchedule(d_model)

optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.9, beta_2=0.98, epsilon=1e-9)

# %%
temp_learning_rate_schedule = CustomSchedule(d_model)

plt.plot(temp_learning_rate_schedule(tf.range(40000, dtype=tf.float32)))
plt.ylabel("Learning Rate")
plt.xlabel("Train Step")
# Out:
# Text(0.5, 0, 'Train Step')

# %% [markdown]
# custom loss and accuracy

# %%
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction='none')
def loss_function(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)

    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask

    return tf.reduce_sum(loss_)/tf.reduce_sum(mask)


def accuracy_function(real, pred):
    accuracies = tf.equal(real, tf.argmax(pred, axis=2))
    #accuracies = tf.cast(accuracies, dtype= tf.float32)

    mask = tf.math.logical_not(tf.math.equal(real, 0))
    accuracies = tf.math.logical_and(mask, accuracies)

    accuracies = tf.cast(accuracies, dtype=tf.float32)
    mask = tf.cast(mask, dtype=tf.float32)
    return tf.reduce_sum(accuracies)/tf.reduce_sum(mask)

# %%
train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.Mean(name='train_accuracy')

# %%
transformer = Transformer(
    num_layers=num_layers,
    d_model=d_model,
    num_heads=num_heads,
    dff=dff,
    input_vocab_size=ENCODER_VOCAB,
    target_vocab_size=DECODER_VOCAB,
    pe_input=1000,
    pe_target=1000,
    rate=dropout_rate)

# %%
def create_look_ahead_mask(size):
    mask = 1 - tf.linalg.band_part(tf.ones((size, size)), -1, 0)
    return mask  # shape: (size, size)

# %%
def create_masks(inp, tar):
    enc_padding_mask = create_padding_mask(inp)  # Mask for the encoder input
    dec_padding_mask = create_padding_mask(inp)  # Mask for the encoder input used in the decoder

    # Create a look-ahead mask for the target sequence
    look_ahead_mask = create_look_ahead_mask(tf.shape(tar)[1])

    # Mask for the target sequence, combining look-ahead and padding mask
    dec_target_padding_mask = create_padding_mask(tar)
    combined_mask = tf.maximum(dec_target_padding_mask, look_ahead_mask)

    return enc_padding_mask, combined_mask, dec_padding_mask, look_ahead_mask

# %%
checkpoint_path = "checkpoints"

ckpt = tf.train.Checkpoint(transformer=transformer, optimizer=optimizer)

ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

if ckpt_manager.latest_checkpoint:
    ckpt.restore(ckpt_manager.latest_checkpoint)
    print ('Latest checkpoint restored!!')

# %%
@tf.function
def train_step(inp, tar):
    tar_inp = tar[:, :-1]
    tar_real = tar[:, 1:]

    # Generate necessary masks
    enc_padding_mask, combined_mask, dec_padding_mask, look_ahead_mask = create_masks(inp, tar_inp)

    with tf.GradientTape() as tape:
        # Pass arguments as keyword arguments
        predictions, _ = transformer(
            inp=inp,  # input sequence
            tar=tar_inp,  # target sequence
            training=True,  # specify the training mode
            enc_padding_mask=enc_padding_mask,  # encoder padding mask
            dec_padding_mask=dec_padding_mask,  # decoder padding mask
            look_ahead_mask=look_ahead_mask  # look-ahead mask
        )

        # Calculate loss
        loss = loss_function(tar_real, predictions)

    # Compute gradients and update model weights
    gradients = tape.gradient(loss, transformer.trainable_variables)
    optimizer.apply_gradients(zip(gradients, transformer.trainable_variables))

    # Update training metrics
    train_loss(loss)
    train_accuracy(accuracy_function(tar_real, predictions))

# %% [markdown]
# training the model

# %%
for epoch in range(EPOCHS):
    start = time.time()

    # Reset metrics at the start of each epoch
    train_loss.reset_state()
    train_accuracy.reset_state()

    # Loop through each batch in the dataset
    for (batch, (inp, tar)) in enumerate(dataset):
        train_step(inp, tar)  # train_step will call create_masks internally

        if batch % 100 == 0:
            # Print batch-level training loss and accuracy every 100 batches
            print(f'Epoch {epoch + 1} Batch {batch} Loss {train_loss.result():.4f} Accuracy {train_accuracy.result():.4f}')

    # Save a checkpoint every 5 epochs
    if (epoch + 1) % 5 == 0:
        ckpt_save_path = ckpt_manager.save()
        print(f'Saving checkpoint for epoch {epoch + 1} at {ckpt_save_path}')

    # Print epoch-level training loss, accuracy, and time taken
    print(f'Epoch {epoch + 1} Loss {train_loss.result():.4f} Accuracy {train_accuracy.result():.4f}')
    print(f'Time taken for 1 epoch: {time.time() - start} secs\n')
# Out:
# Epoch 1 Batch 0 Loss 10.3109 Accuracy 0.0000
# Epoch 1 Batch 100 Loss 10.2095 Accuracy 0.0470
# Epoch 1 Batch 200 Loss 9.9955 Accuracy 0.0708
# Epoch 1 Batch 300 Loss 9.6843 Accuracy 0.0794
# Epoch 1 Batch 400 Loss 9.3404 Accuracy 0.0845
# Epoch 1 Batch 500 Loss 9.0254 Accuracy 0.0886
# Epoch 1 Batch 600 Loss 8.7779 Accuracy 0.0928
# Epoch 1 Batch 700 Loss 8.5817 Accuracy 0.0987
# Epoch 1 Batch 800 Loss 8.4237 Accuracy 0.1038
# Epoch 1 Loss 8.3380 Accuracy 0.1069
# Time taken for 1 epoch: 121.06151270866394 secs
#
# Epoch 2 Batch 0 Loss 7.7451 Accuracy 0.1232
# Epoch 2 Batch 100 Loss 7.3698 Accuracy 0.1230
# Epoch 2 Batch 200 Loss 7.2820 Accuracy 0.1264
# Epoch 2 Batch 300 Loss 7.2014 Accuracy 0.1290
# Epoch 2 Batch 400 Loss 7.1505 Accuracy 0.1324
# Epoch 2 Batch 500 Loss 7.0976 Accuracy 0.1365
# Epoch 2 Batch 600 Loss 7.0422 Accuracy 0.1405
# Epoch 2 Batch 700 Loss 6.9810 Accuracy 0.1446
# Epoch 2 Batch 800 Loss 6.9152 Accuracy 0.1490
# Epoch 2 Loss 6.8723 Accuracy 0.1515
# Time taken for 1 epoch: 92.71344828605652 secs
#
# Epoch 3 Batch 0 Loss 6.9819 Accuracy 0.1268
# Epoch 3 Batch 100 Loss 6.6385 Accuracy 0.1454
# Epoch 3 Batch 200 Loss 6.5496 Accuracy 0.1505
# Epoch 3 Batch 300 Loss 6.4791 Accuracy 0.1551
# Epoch 3 Batch 400 Loss 6.4359 Accuracy 0.1588
# Epoch 3 Batch 500 Loss 6.3929 Accuracy 0.1633
# Epoch 3 Batch 600 Loss 6.3464 Accuracy 0.1683
# Epoch 3 Batch 700 Loss 6.2934 Accuracy 0.1734
# Epoch 3 Batch 800 Loss 6.2330 Accuracy 0.1783
# Epoch 3 Loss 6.1953 Accuracy 0.1814
# Time taken for 1 epoch: 89.62032270431519 secs
#
# Epoch 4 Batch 0 Loss 6.2865 Accuracy 0.1713
# Epoch 4 Batch 100 Loss 6.0923 Accuracy 0.1743
# Epoch 4 Batch 200 Loss 6.0048 Accuracy 0.1814
# Epoch 4 Batch 300 Loss 5.9354 Accuracy 0.1871
# Epoch 4 Batch 400 Loss 5.8972 Accuracy 0.1906
# Epoch 4 Batch 500 Loss 5.8520 Accuracy 0.1961
# Epoch 4 Batch 600 Loss 5.8085 Accuracy 0.2010
# Epoch 4 Batch 700 Loss 5.7570 Accuracy 0.2071
# Epoch 4 Batch 800 Loss 5.6996 Accuracy 0.2129
# Epoch 4 Loss 5.6633 Accuracy 0.2165
# Time taken for 1 epoch: 89.21625065803528 secs
#
# Epoch 5 Batch 0 Loss 6.1368 Accuracy 0.1807
# Epoch 5 Batch 100 Loss 5.6228 Accuracy 0.2098
# Epoch 5 Batch 200 Loss 5.5346 Accuracy 0.2171
# Epoch 5 Batch 300 Loss 5.4687 Accuracy 0.2241
# Epoch 5 Batch 400 Loss 5.4342 Accuracy 0.2277
# Epoch 5 Batch 500 Loss 5.3901 Accuracy 0.2335
# Epoch 5 Batch 600 Loss 5.3473 Accuracy 0.2389
# Epoch 5 Batch 700 Loss 5.2987 Accuracy 0.2450
# Epoch 5 Batch 800 Loss 5.2426 Accuracy 0.2511
# Saving checkpoint for epoch 5 at checkpoints/ckpt-1
# Epoch 5 Loss 5.2072 Accuracy 0.2548
# Time taken for 1 epoch: 90.07570505142212 secs
#
# Epoch 6 Batch 0 Loss 5.7589 Accuracy 0.2146
# Epoch 6 Batch 100 Loss 5.2125 Accuracy 0.2461
# Epoch 6 Batch 200 Loss 5.1228 Accuracy 0.2537
# Epoch 6 Batch 300 Loss 5.0482 Accuracy 0.2613
# Epoch 6 Batch 400 Loss 5.0076 Accuracy 0.2656
# Epoch 6 Batch 500 Loss 4.9560 Accuracy 0.2719
# Epoch 6 Batch 600 Loss 4.9089 Accuracy 0.2775
# Epoch 6 Batch 700 Loss 4.8582 Accuracy 0.2838
# Epoch 6 Batch 800 Loss 4.8010 Accuracy 0.2904
# Epoch 6 Loss 4.7680 Accuracy 0.2941
# Time taken for 1 epoch: 89.16958928108215 secs
#
# Epoch 7 Batch 0 Loss 5.4739 Accuracy 0.2467
# Epoch 7 Batch 100 Loss 4.8356 Accuracy 0.2799
# Epoch 7 Batch 200 Loss 4.7438 Accuracy 0.2879
# Epoch 7 Batch 300 Loss 4.6728 Accuracy 0.2960
# Epoch 7 Batch 400 Loss 4.6308 Accuracy 0.3006
# Epoch 7 Batch 500 Loss 4.5818 Accuracy 0.3070
# Epoch 7 Batch 600 Loss 4.5388 Accuracy 0.3127
# Epoch 7 Batch 700 Loss 4.4909 Accuracy 0.3188
# Epoch 7 Batch 800 Loss 4.4396 Accuracy 0.3254
# Epoch 7 Loss 4.4099 Accuracy 0.3287
# Time taken for 1 epoch: 89.24891304969788 secs
#
# Epoch 8 Batch 0 Loss 5.0948 Accuracy 0.2684
# Epoch 8 Batch 100 Loss 4.5270 Accuracy 0.3092
# Epoch 8 Batch 200 Loss 4.4311 Accuracy 0.3193
# Epoch 8 Batch 300 Loss 4.3648 Accuracy 0.3272
# Epoch 8 Batch 400 Loss 4.3282 Accuracy 0.3320
# Epoch 8 Batch 500 Loss 4.2804 Accuracy 0.3388
# Epoch 8 Batch 600 Loss 4.2391 Accuracy 0.3445
# Epoch 8 Batch 700 Loss 4.1929 Accuracy 0.3508
# Epoch 8 Batch 800 Loss 4.1453 Accuracy 0.3569
# Epoch 8 Loss 4.1178 Accuracy 0.3605
# Time taken for 1 epoch: 89.10220265388489 secs
#
# Epoch 9 Batch 0 Loss 4.8208 Accuracy 0.3039
# Epoch 9 Batch 100 Loss 4.2817 Accuracy 0.3375
# Epoch 9 Batch 200 Loss 4.1870 Accuracy 0.3475
# Epoch 9 Batch 300 Loss 4.1185 Accuracy 0.3555
# Epoch 9 Batch 400 Loss 4.0795 Accuracy 0.3605
# Epoch 9 Batch 500 Loss 4.0320 Accuracy 0.3672
# Epoch 9 Batch 600 Loss 3.9899 Accuracy 0.3736
# Epoch 9 Batch 700 Loss 3.9437 Accuracy 0.3797
# Epoch 9 Batch 800 Loss 3.8989 Accuracy 0.3859
# Epoch 9 Loss 3.8720 Accuracy 0.3891
# Time taken for 1 epoch: 89.00690245628357 secs
#
# Epoch 10 Batch 0 Loss 4.4113 Accuracy 0.3280
# Epoch 10 Batch 100 Loss 4.0680 Accuracy 0.3610
# Epoch 10 Batch 200 Loss 3.9799 Accuracy 0.3718
# Epoch 10 Batch 300 Loss 3.9104 Accuracy 0.3803
# Epoch 10 Batch 400 Loss 3.8699 Accuracy 0.3856
# Epoch 10 Batch 500 Loss 3.8220 Accuracy 0.3931
# Epoch 10 Batch 600 Loss 3.7798 Accuracy 0.3993
# Epoch 10 Batch 700 Loss 3.7351 Accuracy 0.4057
# Epoch 10 Batch 800 Loss 3.6912 Accuracy 0.4116
# Saving checkpoint for epoch 10 at checkpoints/ckpt-2
# Epoch 10 Loss 3.6681 Accuracy 0.4147
# Time taken for 1 epoch: 142.80273342132568 secs
#
# Epoch 11 Batch 0 Loss 4.4022 Accuracy 0.3333
# Epoch 11 Batch 100 Loss 3.8701 Accuracy 0.3861
# Epoch 11 Batch 200 Loss 3.7891 Accuracy 0.3962
# Epoch 11 Batch 300 Loss 3.7239 Accuracy 0.4040
# Epoch 11 Batch 400 Loss 3.6850 Accuracy 0.4094
# Epoch 11 Batch 500 Loss 3.6401 Accuracy 0.4159
# Epoch 11 Batch 600 Loss 3.5983 Accuracy 0.4221
# Epoch 11 Batch 700 Loss 3.5540 Accuracy 0.4284
# Epoch 11 Batch 800 Loss 3.5120 Accuracy 0.4343
# Epoch 11 Loss 3.4898 Accuracy 0.4375
# Time taken for 1 epoch: 90.29828572273254 secs
#
# Epoch 12 Batch 0 Loss 4.2548 Accuracy 0.3418
# Epoch 12 Batch 100 Loss 3.7246 Accuracy 0.4035
# Epoch 12 Batch 200 Loss 3.6352 Accuracy 0.4143
# Epoch 12 Batch 300 Loss 3.5705 Accuracy 0.4227
# Epoch 12 Batch 400 Loss 3.5297 Accuracy 0.4280
# Epoch 12 Batch 500 Loss 3.4809 Accuracy 0.4360
# Epoch 12 Batch 600 Loss 3.4385 Accuracy 0.4423
# Epoch 12 Batch 700 Loss 3.3963 Accuracy 0.4486
# Epoch 12 Batch 800 Loss 3.3580 Accuracy 0.4544
# Epoch 12 Loss 3.3361 Accuracy 0.4577
# Time taken for 1 epoch: 89.0526487827301 secs
#
# Epoch 13 Batch 0 Loss 4.2667 Accuracy 0.3703
# Epoch 13 Batch 100 Loss 3.5772 Accuracy 0.4250
# Epoch 13 Batch 200 Loss 3.4919 Accuracy 0.4332
# Epoch 13 Batch 300 Loss 3.4314 Accuracy 0.4410
# Epoch 13 Batch 400 Loss 3.3957 Accuracy 0.4458
# Epoch 13 Batch 500 Loss 3.3484 Accuracy 0.4540
# Epoch 13 Batch 600 Loss 3.3051 Accuracy 0.4608
# Epoch 13 Batch 700 Loss 3.2650 Accuracy 0.4674
# Epoch 13 Batch 800 Loss 3.2290 Accuracy 0.4732
# Epoch 13 Loss 3.2088 Accuracy 0.4764
# Time taken for 1 epoch: 89.45755648612976 secs
#
# Epoch 14 Batch 0 Loss 3.8316 Accuracy 0.3959
# Epoch 14 Batch 100 Loss 3.4657 Accuracy 0.4434
# Epoch 14 Batch 200 Loss 3.3870 Accuracy 0.4507
# Epoch 14 Batch 300 Loss 3.3238 Accuracy 0.4582
# Epoch 14 Batch 400 Loss 3.2893 Accuracy 0.4634
# Epoch 14 Batch 500 Loss 3.2449 Accuracy 0.4710
# Epoch 14 Batch 600 Loss 3.2059 Accuracy 0.4776
# Epoch 14 Batch 700 Loss 3.1690 Accuracy 0.4836
# Epoch 14 Batch 800 Loss 3.1332 Accuracy 0.4895
# Epoch 14 Loss 3.1134 Accuracy 0.4926
# Time taken for 1 epoch: 89.01181244850159 secs
#
# Epoch 15 Batch 0 Loss 3.8469 Accuracy 0.4052
# Epoch 15 Batch 100 Loss 3.3820 Accuracy 0.4553
# Epoch 15 Batch 200 Loss 3.2897 Accuracy 0.4659
# Epoch 15 Batch 300 Loss 3.2285 Accuracy 0.4738
# Epoch 15 Batch 400 Loss 3.1947 Accuracy 0.4789
# Epoch 15 Batch 500 Loss 3.1497 Accuracy 0.4865
# Epoch 15 Batch 600 Loss 3.1103 Accuracy 0.4929
# Epoch 15 Batch 700 Loss 3.0726 Accuracy 0.4992
# Epoch 15 Batch 800 Loss 3.0374 Accuracy 0.5047
# Saving checkpoint for epoch 15 at checkpoints/ckpt-3
# Epoch 15 Loss 3.0170 Accuracy 0.5079
# Time taken for 1 epoch: 90.39215183258057 secs
#
# Epoch 16 Batch 0 Loss 4.0254 Accuracy 0.4035
# Epoch 16 Batch 100 Loss 3.2754 Accuracy 0.4683
# Epoch 16 Batch 200 Loss 3.1994 Accuracy 0.4773
# Epoch 16 Batch 300 Loss 3.1398 Accuracy 0.4855
# Epoch 16 Batch 400 Loss 3.1025 Accuracy 0.4908
# Epoch 16 Batch 500 Loss 3.0565 Accuracy 0.4991
# Epoch 16 Batch 600 Loss 3.0154 Accuracy 0.5061
# Epoch 16 Batch 700 Loss 2.9763 Accuracy 0.5124
# Epoch 16 Batch 800 Loss 2.9396 Accuracy 0.5183
# Epoch 16 Loss 2.9183 Accuracy 0.5215
# Time taken for 1 epoch: 89.22716617584229 secs
#
# Epoch 17 Batch 0 Loss 3.6134 Accuracy 0.4465
# Epoch 17 Batch 100 Loss 3.1557 Accuracy 0.4828
# Epoch 17 Batch 200 Loss 3.0875 Accuracy 0.4924
# Epoch 17 Batch 300 Loss 3.0307 Accuracy 0.4994
# Epoch 17 Batch 400 Loss 2.9953 Accuracy 0.5047
# Epoch 17 Batch 500 Loss 2.9516 Accuracy 0.5128
# Epoch 17 Batch 600 Loss 2.9104 Accuracy 0.5195
# Epoch 17 Batch 700 Loss 2.8732 Accuracy 0.5257
# Epoch 17 Batch 800 Loss 2.8375 Accuracy 0.5311
# Epoch 17 Loss 2.8163 Accuracy 0.5344
# Time taken for 1 epoch: 88.98802971839905 secs
#
# Epoch 18 Batch 0 Loss 3.5990 Accuracy 0.4431
# Epoch 18 Batch 100 Loss 3.0515 Accuracy 0.4939
# Epoch 18 Batch 200 Loss 2.9843 Accuracy 0.5038
# Epoch 18 Batch 300 Loss 2.9280 Accuracy 0.5117
# Epoch 18 Batch 400 Loss 2.8947 Accuracy 0.5177
# Epoch 18 Batch 500 Loss 2.8474 Accuracy 0.5259
# Epoch 18 Batch 600 Loss 2.8064 Accuracy 0.5329
# Epoch 18 Batch 700 Loss 2.7691 Accuracy 0.5392
# Epoch 18 Batch 800 Loss 2.7346 Accuracy 0.5447
# Epoch 18 Loss 2.7151 Accuracy 0.5477
# Time taken for 1 epoch: 89.09345936775208 secs
#
# Epoch 19 Batch 0 Loss 3.5751 Accuracy 0.4556
# Epoch 19 Batch 100 Loss 2.9409 Accuracy 0.5089
# Epoch 19 Batch 200 Loss 2.8777 Accuracy 0.5179
# Epoch 19 Batch 300 Loss 2.8261 Accuracy 0.5254
# Epoch 19 Batch 400 Loss 2.7955 Accuracy 0.5305
# Epoch 19 Batch 500 Loss 2.7493 Accuracy 0.5387
# Epoch 19 Batch 600 Loss 2.7097 Accuracy 0.5457
# Epoch 19 Batch 700 Loss 2.6715 Accuracy 0.5521
# Epoch 19 Batch 800 Loss 2.6384 Accuracy 0.5575
# Epoch 19 Loss 2.6188 Accuracy 0.5607
# Time taken for 1 epoch: 89.26627326011658 secs
#
# Epoch 20 Batch 0 Loss 3.3404 Accuracy 0.4411
# Epoch 20 Batch 100 Loss 2.8637 Accuracy 0.5182
# Epoch 20 Batch 200 Loss 2.7921 Accuracy 0.5274
# Epoch 20 Batch 300 Loss 2.7405 Accuracy 0.5355
# Epoch 20 Batch 400 Loss 2.7087 Accuracy 0.5409
# Epoch 20 Batch 500 Loss 2.6617 Accuracy 0.5493
# Epoch 20 Batch 600 Loss 2.6241 Accuracy 0.5565
# Epoch 20 Batch 700 Loss 2.5861 Accuracy 0.5630
# Epoch 20 Batch 800 Loss 2.5549 Accuracy 0.5685
# Saving checkpoint for epoch 20 at checkpoints/ckpt-4
# Epoch 20 Loss 2.5352 Accuracy 0.5717
# Time taken for 1 epoch: 90.03133225440979 secs
#
# Epoch 21 Batch 0 Loss 3.4621 Accuracy 0.4568
# Epoch 21 Batch 100 Loss 2.7747 Accuracy 0.5294
# Epoch 21 Batch 200 Loss 2.7042 Accuracy 0.5389
# Epoch 21 Batch 300 Loss 2.6588 Accuracy 0.5461
# Epoch 21 Batch 400 Loss 2.6256 Accuracy 0.5521
# Epoch 21 Batch 500 Loss 2.5811 Accuracy 0.5605
# Epoch 21 Batch 600 Loss 2.5427 Accuracy 0.5674
# Epoch 21 Batch 700 Loss 2.5054 Accuracy 0.5738
# Epoch 21 Batch 800 Loss 2.4744 Accuracy 0.5791
# Epoch 21 Loss 2.4565 Accuracy 0.5823
# Time taken for 1 epoch: 89.08089637756348 secs
#
# Epoch 22 Batch 0 Loss 3.1878 Accuracy 0.4594
# Epoch 22 Batch 100 Loss 2.6941 Accuracy 0.5419
# Epoch 22 Batch 200 Loss 2.6315 Accuracy 0.5489
# Epoch 22 Batch 300 Loss 2.5824 Accuracy 0.5569
# Epoch 22 Batch 400 Loss 2.5511 Accuracy 0.5620
# Epoch 22 Batch 500 Loss 2.5104 Accuracy 0.5698
# Epoch 22 Batch 600 Loss 2.4692 Accuracy 0.5775
# Epoch 22 Batch 700 Loss 2.4329 Accuracy 0.5838
# Epoch 22 Batch 800 Loss 2.4020 Accuracy 0.5893
# Epoch 22 Loss 2.3846 Accuracy 0.5924
# Time taken for 1 epoch: 88.99497532844543 secs
#
# Epoch 23 Batch 0 Loss 3.3375 Accuracy 0.4964
# Epoch 23 Batch 100 Loss 2.6254 Accuracy 0.5516
# Epoch 23 Batch 200 Loss 2.5620 Accuracy 0.5602
# Epoch 23 Batch 300 Loss 2.5148 Accuracy 0.5678
# Epoch 23 Batch 400 Loss 2.4828 Accuracy 0.5728
# Epoch 23 Batch 500 Loss 2.4434 Accuracy 0.5805
# Epoch 23 Batch 600 Loss 2.4037 Accuracy 0.5875
# Epoch 23 Batch 700 Loss 2.3686 Accuracy 0.5935
# Epoch 23 Batch 800 Loss 2.3390 Accuracy 0.5987
# Epoch 23 Loss 2.3220 Accuracy 0.6016
# Time taken for 1 epoch: 89.19838285446167 secs
#
# Epoch 24 Batch 0 Loss 2.9619 Accuracy 0.5225
# Epoch 24 Batch 100 Loss 2.5583 Accuracy 0.5606
# Epoch 24 Batch 200 Loss 2.5023 Accuracy 0.5681
# Epoch 24 Batch 300 Loss 2.4516 Accuracy 0.5757
# Epoch 24 Batch 400 Loss 2.4258 Accuracy 0.5808
# Epoch 24 Batch 500 Loss 2.3844 Accuracy 0.5892
# Epoch 24 Batch 600 Loss 2.3441 Accuracy 0.5970
# Epoch 24 Batch 700 Loss 2.3089 Accuracy 0.6035
# Epoch 24 Batch 800 Loss 2.2795 Accuracy 0.6085
# Epoch 24 Loss 2.2626 Accuracy 0.6116
# Time taken for 1 epoch: 89.24076223373413 secs
#
# Epoch 25 Batch 0 Loss 3.0092 Accuracy 0.5188
# Epoch 25 Batch 100 Loss 2.5038 Accuracy 0.5698
# Epoch 25 Batch 200 Loss 2.4484 Accuracy 0.5774
# Epoch 25 Batch 300 Loss 2.3957 Accuracy 0.5844
# Epoch 25 Batch 400 Loss 2.3690 Accuracy 0.5894
# Epoch 25 Batch 500 Loss 2.3297 Accuracy 0.5971
# Epoch 25 Batch 600 Loss 2.2923 Accuracy 0.6045
# Epoch 25 Batch 700 Loss 2.2562 Accuracy 0.6112
# Epoch 25 Batch 800 Loss 2.2267 Accuracy 0.6165
# Saving checkpoint for epoch 25 at checkpoints/ckpt-5
# Epoch 25 Loss 2.2106 Accuracy 0.6193
# Time taken for 1 epoch: 90.0212128162384 secs
#
# Epoch 26 Batch 0 Loss 2.9132 Accuracy 0.5212
# Epoch 26 Batch 100 Loss 2.4542 Accuracy 0.5763
# Epoch 26 Batch 200 Loss 2.3906 Accuracy 0.5853
# Epoch 26 Batch 300 Loss 2.3490 Accuracy 0.5927
# Epoch 26 Batch 400 Loss 2.3171 Accuracy 0.5977
# Epoch 26 Batch 500 Loss 2.2771 Accuracy 0.6060
# Epoch 26 Batch 600 Loss 2.2380 Accuracy 0.6129
# Epoch 26 Batch 700 Loss 2.2035 Accuracy 0.6193
# Epoch 26 Batch 800 Loss 2.1757 Accuracy 0.6243
# Epoch 26 Loss 2.1596 Accuracy 0.6270
# Time taken for 1 epoch: 89.25130200386047 secs
#
# Epoch 27 Batch 0 Loss 2.6604 Accuracy 0.5516
# Epoch 27 Batch 100 Loss 2.3945 Accuracy 0.5871
# Epoch 27 Batch 200 Loss 2.3346 Accuracy 0.5937
# Epoch 27 Batch 300 Loss 2.2972 Accuracy 0.6000
# Epoch 27 Batch 400 Loss 2.2680 Accuracy 0.6054
# Epoch 27 Batch 500 Loss 2.2281 Accuracy 0.6135
# Epoch 27 Batch 600 Loss 2.1913 Accuracy 0.6203
# Epoch 27 Batch 700 Loss 2.1566 Accuracy 0.6268
# Epoch 27 Batch 800 Loss 2.1308 Accuracy 0.6318
# Epoch 27 Loss 2.1159 Accuracy 0.6344
# Time taken for 1 epoch: 89.19649624824524 secs
#
# Epoch 28 Batch 0 Loss 2.7617 Accuracy 0.5411
# Epoch 28 Batch 100 Loss 2.3569 Accuracy 0.5936
# Epoch 28 Batch 200 Loss 2.3001 Accuracy 0.6005
# Epoch 28 Batch 300 Loss 2.2551 Accuracy 0.6075
# Epoch 28 Batch 400 Loss 2.2262 Accuracy 0.6125
# Epoch 28 Batch 500 Loss 2.1863 Accuracy 0.6205
# Epoch 28 Batch 600 Loss 2.1493 Accuracy 0.6274
# Epoch 28 Batch 700 Loss 2.1163 Accuracy 0.6338
# Epoch 28 Batch 800 Loss 2.0895 Accuracy 0.6387
# Epoch 28 Loss 2.0743 Accuracy 0.6415
# Time taken for 1 epoch: 89.03233027458191 secs
#
# Epoch 29 Batch 0 Loss 2.6258 Accuracy 0.5568
# Epoch 29 Batch 100 Loss 2.3168 Accuracy 0.5991
# Epoch 29 Batch 200 Loss 2.2561 Accuracy 0.6074
# Epoch 29 Batch 300 Loss 2.2115 Accuracy 0.6143
# Epoch 29 Batch 400 Loss 2.1850 Accuracy 0.6194
# Epoch 29 Batch 500 Loss 2.1426 Accuracy 0.6277
# Epoch 29 Batch 600 Loss 2.1068 Accuracy 0.6347
# Epoch 29 Batch 700 Loss 2.0748 Accuracy 0.6407
# Epoch 29 Batch 800 Loss 2.0468 Accuracy 0.6456
# Epoch 29 Loss 2.0325 Accuracy 0.6484
# Time taken for 1 epoch: 89.29908442497253 secs
#
# Epoch 30 Batch 0 Loss 2.7113 Accuracy 0.5634
# Epoch 30 Batch 100 Loss 2.2799 Accuracy 0.6052
# Epoch 30 Batch 200 Loss 2.2116 Accuracy 0.6136
# Epoch 30 Batch 300 Loss 2.1677 Accuracy 0.6204
# Epoch 30 Batch 400 Loss 2.1413 Accuracy 0.6258
# Epoch 30 Batch 500 Loss 2.1002 Accuracy 0.6340
# Epoch 30 Batch 600 Loss 2.0678 Accuracy 0.6406
# Epoch 30 Batch 700 Loss 2.0346 Accuracy 0.6469
# Epoch 30 Batch 800 Loss 2.0106 Accuracy 0.6513
# Saving checkpoint for epoch 30 at checkpoints/ckpt-6
# Epoch 30 Loss 1.9961 Accuracy 0.6541
# Time taken for 1 epoch: 90.124755859375 secs

# %% [markdown]
# evaluation

# %%
def evaluate(input_article):
    input_article = article_tokenizer.texts_to_sequences([input_article])
    input_article = tf.keras.preprocessing.sequence.pad_sequences(input_article, maxlen=ENCODER_LEN,
                                                                   padding='post', truncating='post')

    encoder_input = tf.expand_dims(input_article[0], 0)

    decoder_input = [summary_tokenizer.word_index['<sos>']]
    output = tf.expand_dims(decoder_input, 0)

    for i in range(DECODER_LEN):
        enc_padding_mask, combined_mask, dec_padding_mask, look_ahead_mask = create_masks(encoder_input, output)

        # Call transformer without combined_mask if it's not expected
        predictions, attention_weights = transformer(
            encoder_input,
            output,
            training=False,  # Fix: passed as keyword argument
            enc_padding_mask=enc_padding_mask,
            dec_padding_mask=dec_padding_mask,
            look_ahead_mask=look_ahead_mask  # If combined_mask is not needed, leave it out
        )

        predictions = predictions[:, -1:, :]
        predicted_id = tf.cast(tf.argmax(predictions, axis=-1), tf.int32)

        if predicted_id == summary_tokenizer.word_index['<eos>']:
            return tf.squeeze(output, axis=0), attention_weights

        output = tf.concat([output, predicted_id], axis=-1)

    return tf.squeeze(output, axis=0), attention_weights

# %%
len(duc)
# Out:
# 500

# %%
def summarize(input_article):
    input_article=preprocess(input_article)
    summarized = evaluate(input_article=input_article)[0].numpy()
    summarized = np.expand_dims(summarized[1:], 0)
    return summary_tokenizer.sequences_to_texts(summarized)[0]

# %%
test_accuracy = tf.keras.metrics.Mean(name='test_accuracy')



pred2 = []
for i in duc['Short']:
    # print(summarize(i))
    pred2.append(summarize(i))
rel2 = []
for i in duc['Headline']:
    rel2.append(i)

test_accuracy(accuracy_function(rel2, pred2))
print('Test Accuracy {}'.format(test_accuracy.result()))

# %%
duc['Short'][1]
# Out:
# "king norodom sihanouk has declined requests to chair a summit of cambodia 's top political leaders , saying the meeting would not bring any progress in deadlocked negotiations to form a government .\n"

# %%
print(summarize(duc['Short'][1]))
# Out:
# strip king of cambodia to form political leaders

# %%
inshorts_new = df.head(10)
inshorts_new
# Out:
#                                             Headline  \
# 0  4 ex-bank officials booked for cheating bank o...
# 1     Supreme Court to go paperless in 6 months: CJI
# 2  At least 3 killed, 30 injured in blast in Sylh...
# 3  Why has Reliance been barred from trading in f...
# 4  Was stopped from entering my own studio at Tim...
# 5   New trailer of &#39;Justice League&#39; released
# 6  His touch was not right: Shilpa Shinde on sexu...
# 7  Anti-Romeo squads must not trouble consenting ...
# 8  Both Romeo and Juliet are welcome in Delhi: AA...
# 9  30 blasts occur at ordnance factory in MP,  20...
#
#                                                Short
# 0  The CBI on Saturday booked four former officia...
# 1  Chief Justice JS Khehar has said the Supreme C...
# 2  At least three people were killed, including a...
# 3  Mukesh Ambani-led Reliance Industries (RIL) wa...
# 4  TV news anchor Arnab Goswami has said he was t...
# 5  A new trailer for the upcoming superhero film ...
# 6  Television actress Shilpa Shinde, while openin...
# 7  Uttar Pradesh Chief Minister Yogi Adityanath, ...
# 8  In an apparent jibe at UP&#39;s anti-Romeo squ...
# 9  At least 20 people were reportedly injured aft...

# %%
pred2 = []
for i in inshorts_new['Short']:
    # print(summarize(i))
    pred2.append(summarize(i))
rel2 = []
for i in inshorts_new['Headline']:
    rel2.append(i)

# %%
pred2
# Out:
# ['4 ex bank officials booked for cheating bank',
#  'six months to go waste in committee',
#  '3 killed 30 injured in two explosions in bangladesh',
#  'over 10k stake in reliance jio s sale in nearly',
#  'was told not to enter live goods before nov 2',
#  'new trailer of justice league released',
#  'was raped harassed says shilpa shetty',
#  'anti pole aus open sources in got from got out',
#  'there are like animals in the red corner naqvi',
#  '20 injured in 20 blasts targeting manali']

# %% [markdown]
# predictions

# %%
rel2
# Out:
# ['Cambodian leader Hun Sen rejects opposition demands for talks in Beijing.\n',
#  'Sihanouk refuses to chair Cambodian political summit at home or abroad\n',
#  'Opponents of Cambodian government ask Asian Development Bank to stop loans\n',
#  'Cambodian party defends leader Hun Sen against criticism of U.S. House\n',
#  'Cambodian party rejects government offer to share legislative office\n',
#  "Political deadlock broken, Hun Sen to be Cambodia's prime minister\n",
#  'Hun Sen, Prince Ranariddh share power in new coalition Cambodian government\n',
#  'Hun Sen guarantees safety and freedom, political opponents remain wary\n',
#  'Cambodian opposition leader doubts safety guaranty of prime minister\n',
#  'King praises Cambodian coalition government of top two political parties\n']

# %%
test_accuracy = tf.keras.metrics.Mean(name='test_accuracy')

pred2 = []
for i in inshorts_new['Short']:
    pred2.append(summarize(i))

rel2 = []
for i in inshorts_new['Headline']:
    rel2.append(i)

test_accuracy(accuracy_function(rel2, pred2))
print('Test Accuracy {}'.format(test_accuracy.result()))
# Out:
# Test Accuracy 0.30000001192092896

# %%
article[6]
# Out:
# '<SOS> Television actress Shilpa Shinde, while opening up about her claims of how Sanjay Kohli sexually harassed her, said, "I could feel... (his) touch was not right." She added, "I am telling this now because it has been one year but the memory is still fresh. The manner in which they behaved with me. I have been sick for seven-eight months." <EOS>'

# %%
print("Real Headline : ", summary[6][5:-5],"\n Predicted Summary : ", summarize(article[6]))
# Out:
# Real Headline :   His touch was not right: Shilpa Shinde on sexual harassment
#  Predicted Summary :  was raped harassed says shilpa shetty

# %%
article[16]
# Out:
# '<SOS> As a part of an education initiative, the entire Wankhede Stadium will be reserved for underprivileged children for the IPL 2017 match between Mumbai Indians and Gujarat Lions, to be held on April 16. A statement by the Mumbai Indians read that they will not be selling any stand tickets for the team`s third home game, against the Gujarat Lions. <EOS>'

# %%
print("Real Headline : ", summary[16][5:-5],"\nPredicted Summary : ", summarize(article[16]))
# Out:
# Real Headline :   Underprivileged kids to fill Wankhede during MI`s IPL match
# Predicted Summary :  man to consider underprivileged kids in ipl match

# %%
article[23]
# Out:
# '<SOS> Uttar Pradesh`s Deputy Chief Minister Dinesh Sharma on Saturday said that a transparent system to end cheating in the state board exams will be brought in. "Every department and organisation concerned has been given instructions and I am personally monitoring it," he added. This comes after class X students were caught mass cheating on camera at a Ballia school. <EOS>'

# %%
print("Real Headline : ", summary[23][5:-5],"\nPredicted Summary : ", summarize(article[23]))
# Out:
# Real Headline :   UP govt assures transparent system to end cheating in exams
# Predicted Summary :  up to end cheating system in exam cm

# %%
print("Real Headline : ", summary[0][5:-5],"\nPredicted Summary : ", summarize(article[0]))
# Out:
# Real Headline :   4 ex-bank officials booked for cheating bank of ₹209 crore
# Predicted Summary :  4 ex bank officials booked for cheating bank

# %%
print("Real Headline : ", summary[23][5:-5],"\nPredicted Summary : ", summarize(article[23]))
# Out:
# Real Headline :   UP govt assures transparent system to end cheating in exams
# Predicted Summary :  up to end cheating system in exam cm

# %%
summarize("Text Summarization - as the name suggests - involves generating short summaries of text data, in a few words or sentences. A good example of this in day-to-day life is the Inshorts news summary app, which generates summaries upto max of ~ 60 words.")
# Out:
# 'creator calls for remarks on sets of intolerance'

# %%
summarize("""Cambodian leader Hun Sen on Friday rejected opposition parties' demands
for talks outside the country, accusing them of trying to ``internationalize''
the political crisis. Government and opposition parties have asked
King Norodom Sihanouk to host a summit meeting after a series of post-election
negotiations between the two opposition groups and Hun Sen's party
to form a new government failed. Opposition leaders Prince Norodom
Ranariddh and Sam Rainsy, citing Hun Sen's threats to arrest opposition
figures after two alleged attempts on his life, said they could not
negotiate freely in Cambodia and called for talks at Sihanouk's residence
in Beijing. Hun Sen, however, rejected that. ``I would like to make
it clear that all meetings related to Cambodian affairs must be conducted
in the Kingdom of Cambodia,'' Hun Sen told reporters after a Cabinet
meeting on Friday. ``No-one should internationalize Cambodian affairs.
It is detrimental to the sovereignty of Cambodia,'' he said. Hun Sen's
Cambodian People's Party won 64 of the 122 parliamentary seats in
July's elections, short of the two-thirds majority needed to form
a government on its own. Ranariddh and Sam Rainsy have charged that
Hun Sen's victory in the elections was achieved through widespread
fraud. They have demanded a thorough investigation into their election
complaints as a precondition for their cooperation in getting the
national assembly moving and a new government formed. Hun Sen said
on Friday that the opposition concerns over their safety in the country
was ``just an excuse for them to stay abroad.'' Both Ranariddh and
Sam Rainsy have been outside the country since parliament was ceremonially
opened on Sep. 24. Sam Rainsy and a number of opposition figures have
been under court investigation for a grenade attack on Hun Sen's Phnom
Penh residence on Sep. 7. Hun Sen was not home at the time of the
attack, which was followed by a police crackdown on demonstrators
contesting Hun Sen's election victory. The Sam Rainsy Party, in a
statement released Friday, accused Hun Sen of being ``unwilling to
make any compromise'' on negotiations to break the deadlock. ``A meeting
outside Cambodia, as suggested by the opposition, could place all
parties on more equal footing,'' said the statement. ``But the ruling
party refuses to negotiate unless it is able to threaten its negotiating
partners with arrest or worse.'' """)
# Out:
# 'sheena bora case against congress officials for 2015'

# %%
summarize("cambodian leader hun sen on friday rejected opposition parties ' demands for talks outside the country , accusing them of trying to `` internationalize '' the political crisis .")
# Out:
# 'sheena bora case convict rejects charges for 2015'

# %%
summarize("king norodom sihanouk has declined requests to chair a summit of cambodia 's top political leaders , saying the meeting would not bring any progress in deadlocked negotiations to form a government .")
# Out:
# 'strip king of cambodia to form political leaders'

# %%
summarize("sometime in the summer of 1997 , an operative for osama bin laden sat down at his personal computer in a hideaway in kenya , he was worried , he wrote in an angry dispatch , about the security of the `` east africa network '' of bin laden , the saudi exile accused of masterminding a worldwide terrorist conspiracy against americans .")
# Out:
# 'pablo escobar s led series man eats videos at jnu'

# %%
summarize("six months after president clinton traveled to beijing and challenged china 's leaders to move rapidly toward political reform , the administration 's policy of engaging beijing was called into question monday when chinese courts sentenced three of the nation 's most prominent dissidents to long jail sentences .")
# Out:
# '6 months against clinton emails'

# %%
summarize("fbi agents this week began questioning relatives of the victims of the aug. 7 u.s. embassy bombing as well as the seriously injured on request of the u.s. attorney 's office for the southern district of new york , a u.s. official said thursday .")
# Out:
# 'fbi demands 7 security flaws in u khand'

# %%
summarize("Saurav Kant, an alumnus of upGrad and IIIT-B's PG Program in Machine learning and Artificial Intelligence, was a Sr Systems Engineer at Infosys with almost 5 years of work experience. The program and upGrad's 360-degree career support helped him transition to a Data Scientist at Tech Mahindra with 90% salary hike. upGrad's Online Power Learning has powered 3 lakh+ careers.")
# Out:
# '50 million hiring program for ai program'

# %%
summarize("Actor Ranbir Kapoor worked as an assistant director for Sanjay Leela Bhansali&#39;s &#39;Black&#39; in 2005. He is also known to have assisted in the making of the 1996 film &#39;PremGranth&#39; and his father Rishi Kapoor&#39;s directorial debut &#39;Aa Ab Laut Chalen&#39; in 1999. The actor, who has won five Filmfare awards including Best Actor for &#39;Barfi!&#39;, turned 34 on Wednesday.")
# Out:
# 'ranbir worked as new reports of black films'

# %%
print("Real Headline : ", summary[0][5:-5],"\nPredicted Summary : ", summarize(article[0]))
# Out:
# Real Headline :   4 ex-bank officials booked for cheating bank of ₹209 crore
# Predicted Summary :  4 ex bank officials booked for cheating bank

# %%
summarize("The CBI on Saturday booked four former officials of Syndicate Bank and six others for cheating, forgery, criminal conspiracy and causing ₹209 crore loss to the state-run bank. The accused had availed home loans and credit from Syndicate Bank on the basis of forged and fabricated documents. These funds were fraudulently transferred to the companies owned by the accused persons.")
# Out:
# '4 ex bank officials booked for cheating bank'

# %%
duc_new = duc.head(10)
duc_new
# Out:
#                                                Short  \
# 0  cambodian leader hun sen on friday rejected op...
# 1  king norodom sihanouk has declined requests to...
# 2  cambodia 's two-party opposition asked the asi...
# 3  cambodia 's ruling party responded tuesday to ...
# 4  cambodia 's leading opposition party ruled out...
# 5  cambodia 's bickering political parties broke ...
# 6  cambodian politicians expressed hope monday th...
# 7  cambodian leader hun sen has guaranteed the sa...
# 8  worried that party colleagues still face arres...
# 9  king norodom sihanouk on tuesday praised agree...
#
#                                             Headline
# 0  Cambodian leader Hun Sen rejects opposition de...
# 1  Sihanouk refuses to chair Cambodian political ...
# 2  Opponents of Cambodian government ask Asian De...
# 3  Cambodian party defends leader Hun Sen against...
# 4  Cambodian party rejects government offer to sh...
# 5  Political deadlock broken, Hun Sen to be Cambo...
# 6  Hun Sen, Prince Ranariddh share power in new c...
# 7  Hun Sen guarantees safety and freedom, politic...
# 8  Cambodian opposition leader doubts safety guar...
# 9  King praises Cambodian coalition government of...

# %%
import tensorflow as tf
import numpy as np
from sentence_transformers import SentenceTransformer, util

# ... (Your existing code for evaluate, summarize, and other functions) ...

# Initialize the SentenceTransformer model
model = SentenceTransformer('all-MiniLM-L6-v2')

def accuracy_function(real, pred):
    """
    Calculates the accuracy between the real and predicted summaries using cosine similarity.

    Args:
        real: A list of real summaries (strings).
        pred: A list of predicted summaries (strings).

    Returns:
        The accuracy score as a float.
    """
    correct_predictions = 0
    for i in range(len(real)):
        embeddings1 = model.encode(real[i], convert_to_tensor=True)
        embeddings2 = model.encode(pred[i], convert_to_tensor=True)
        cosine_scores = util.cos_sim(embeddings1, embeddings2)
        if cosine_scores.item() >= 0.6:
            correct_predictions += 1
    accuracy = correct_predictions / len(real)
    # Convert accuracy to a TensorFlow tensor before returning
    return tf.constant(accuracy, dtype=tf.float32)

# ... (Your existing code for duc_new DataFrame) ...

test_accuracy = tf.keras.metrics.Mean(name='test_accuracy')

pred2 = []
for i in duc_new['Short']:
    pred2.append(summarize(i))

rel2 = []
for i in duc_new['Headline']:
    rel2.append(i)

test_accuracy(accuracy_function(rel2, pred2))
print('Test Accuracy {}'.format(test_accuracy.result()))
# Out:
# Test Accuracy 0.0
