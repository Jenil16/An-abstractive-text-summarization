# %%
# !pip install openpyxl  --quiet

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from collections import defaultdict
import string
import tensorflow as tf
import re
import os
import time
from tensorflow import keras
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split

# %%
ENCODER_LEN = 100
DECODER_LEN = 20
BATCH_SIZE = 64
BUFFER_SIZE = BATCH_SIZE*8
# Out:
# time: 1.66 ms (started: 2024-12-03 19:25:13 +00:00)

# %%
duc=pd.read_excel("/content/drive/MyDrive/Colab Notebooks/DL/Datasets/duc_2004.xlsx",engine = 'openpyxl')

# %%
duc.head()
# Out:
#                                                 text  \
# 0  cambodian leader hun sen on friday rejected op...
# 1  king norodom sihanouk has declined requests to...
# 2  cambodia 's two-party opposition asked the asi...
# 3  cambodia 's ruling party responded tuesday to ...
# 4  cambodia 's leading opposition party ruled out...
#
#                                             summary1  \
# 0  Cambodian government rejects opposition's call...
# 1  Sihanouk refuses to chair Cambodian political ...
# 2  Opposition asks end to loans to "illegal" Camb...
# 3  Cambodian party defends leader Hun Sen against...
# 4  Cambodian party rejects government offer to sh...
#
#                                             summary2  \
# 0  Cambodian leader Hun Sen rejects opposition de...
# 1  Sihanouk refuses to host talks of Cambodian po...
# 2  Cambodian opposition asks ADB to stop loans to...
# 3  CPP defends Hun Sen to US Senate. Asks rejecti...
# 4  FUNCINPEC refuses to share presidency with CPP...
#
#                                             summary3  \
# 0  Hun Sen rejects out of country talks, Sihanouk...
# 1  Efforts to form a government deadlocked, Sihan...
# 2  Cambodia's two-party opposition seeks to block...
# 3  Cambodia's ruling party seeks to counter human...
# 4  Disputes over presidency block efforts to form...
#
#                                             summary4
# 0  New Cambodian government in limbo as Hun Sen r...
# 1  Norodom Sihanouk declines role to mediate in C...
# 2  Opponents of Cambodian government ask Asian De...
# 3  US House seeks probe of Cambodian rights viola...
# 4  Opposition Royalists reject power sharing and ...

# %%
news = pd.read_excel("/content/drive/MyDrive/Copy of inshorts.xlsx",engine = 'openpyxl')
news.drop(['Source ', 'Time ', 'Publish Date'], axis=1, inplace=True)
news.head()
print(f'Dataset size: {len(news)}')
# Out:
# Dataset size: 55104

# %%
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer

# Load the DUC dataset
df = duc.copy()  # Make a copy of the DataFrame to avoid modifying the original
# Initialize the embedding model (using Sentence Transformers)
model = SentenceTransformer('all-MiniLM-L6-v2')

# Preprocess the dataset (keeping the relevant text and summaries)
# Assuming the dataset has columns: 'text', 'summary1', 'summary2', 'summary3', 'summary4'
texts = df['text'].tolist()
summaries = df[['summary1', 'summary2', 'summary3', 'summary4']].values

# Encode texts and summaries
text_embeddings = model.encode(texts, convert_to_tensor=True)
summary_embeddings = [model.encode([summaries[i][j] for j in range(4)], convert_to_tensor=True) for i in range(len(summaries))]

# Find the summary with the highest similarity for each text
best_summaries = []
for i, text_embedding in enumerate(text_embeddings):
    # Calculate cosine similarities between the text and each summary
    similarities = cosine_similarity([text_embedding.cpu().numpy()], [summary.cpu().numpy() for summary in summary_embeddings[i]])

    # Get the index of the summary with the highest similarity
    best_summary_index = similarities.argmax()
    best_summaries.append(summaries[i][best_summary_index])

# Add the best summary to the dataframe and drop other summary columns
df['best_summary'] = best_summaries
df = df[['text', 'best_summary']]  # Keep only the text and the best summary

# Save the processed dataset
df.to_csv("processed_duc_dataset.csv", index=False)

print("Processed dataset saved with the best summary for each text!")
# Out:
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Processed dataset saved with the best summary for each text!

# %%
duc = pd.read_csv("/content/processed_duc_dataset.csv")
duc.head()
# Out:
#                                                 text  \
# 0  cambodian leader hun sen on friday rejected op...
# 1  king norodom sihanouk has declined requests to...
# 2  cambodia 's two-party opposition asked the asi...
# 3  cambodia 's ruling party responded tuesday to ...
# 4  cambodia 's leading opposition party ruled out...
#
#                                         best_summary
# 0  Cambodian leader Hun Sen rejects opposition de...
# 1  Sihanouk refuses to chair Cambodian political ...
# 2  Opponents of Cambodian government ask Asian De...
# 3  Cambodian party defends leader Hun Sen against...
# 4  Cambodian party rejects government offer to sh...

# %%
# duc_columns = duc.columns.tolist()
# duc_columns.remove('text')
# duc_columns.remove('summary1')
# duc.drop(duc_columns, axis='columns', inplace=True)

# %%
duc
# Out:
#                                                   text  \
# 0    cambodian leader hun sen on friday rejected op...
# 1    king norodom sihanouk has declined requests to...
# 2    cambodia 's two-party opposition asked the asi...
# 3    cambodia 's ruling party responded tuesday to ...
# 4    cambodia 's leading opposition party ruled out...
# ..                                                 ...
# 495  german foreign minister joschka fischer , who ...
# 496  the trials of three outspoken dissidents over ...
# 497  his friend and political mentor is jailed , ro...
# 498  by sentencing two of the country 's most promi...
# 499  six months after president clinton traveled to...
#
#                                           best_summary
# 0    Cambodian leader Hun Sen rejects opposition de...
# 1    Sihanouk refuses to chair Cambodian political ...
# 2    Opponents of Cambodian government ask Asian De...
# 3    Cambodian party defends leader Hun Sen against...
# 4    Cambodian party rejects government offer to sh...
# ..                                                 ...
# 495  German Foreign Minister calls China's sentenci...
# 496  China renews crackdown on political activists;...
# 497  China Democracy Party, Zha, legally subversive...
# 498  China: two pro-democracy politicians given lon...
# 499  Clinton, China policy, Jiang, Xu, Wang, Qin, h...
#
# [500 rows x 2 columns]

# %%
duc.rename(columns = { 'best_summary':'Headline','text':'Short'}, inplace = True)

# %%
duc
# Out:
#                                                  Short  \
# 0    cambodian leader hun sen on friday rejected op...
# 1    king norodom sihanouk has declined requests to...
# 2    cambodia 's two-party opposition asked the asi...
# 3    cambodia 's ruling party responded tuesday to ...
# 4    cambodia 's leading opposition party ruled out...
# ..                                                 ...
# 495  german foreign minister joschka fischer , who ...
# 496  the trials of three outspoken dissidents over ...
# 497  his friend and political mentor is jailed , ro...
# 498  by sentencing two of the country 's most promi...
# 499  six months after president clinton traveled to...
#
#                                               Headline
# 0    Cambodian leader Hun Sen rejects opposition de...
# 1    Sihanouk refuses to chair Cambodian political ...
# 2    Opponents of Cambodian government ask Asian De...
# 3    Cambodian party defends leader Hun Sen against...
# 4    Cambodian party rejects government offer to sh...
# ..                                                 ...
# 495  German Foreign Minister calls China's sentenci...
# 496  China renews crackdown on political activists;...
# 497  China Democracy Party, Zha, legally subversive...
# 498  China: two pro-democracy politicians given lon...
# 499  Clinton, China policy, Jiang, Xu, Wang, Qin, h...
#
# [500 rows x 2 columns]

# %%
news
# Out:
#                                                 Headline  \
# 0      4 ex-bank officials booked for cheating bank o...
# 1         Supreme Court to go paperless in 6 months: CJI
# 2      At least 3 killed, 30 injured in blast in Sylh...
# 3      Why has Reliance been barred from trading in f...
# 4      Was stopped from entering my own studio at Tim...
# ...                                                  ...
# 55099         Sensex loses 400 points to hit 52-week low
# 55100      China to inject $91 bn into the money markets
# 55101   Ghulam Ali set to make acting debut in Bollywood
# 55102       IS acknowledges death of Jihadi John: Report
# 55103        Cairn to seek $600 mn from India in damages
#
#                                                    Short
# 0      The CBI on Saturday booked four former officia...
# 1      Chief Justice JS Khehar has said the Supreme C...
# 2      At least three people were killed, including a...
# 3      Mukesh Ambani-led Reliance Industries (RIL) wa...
# 4      TV news anchor Arnab Goswami has said he was t...
# ...                                                  ...
# 55099  Tracking weak cues from the Asian markets, the...
# 55100  Amid growing concerns about China&#39;s econom...
# 55101  Pakistani Ghazal singer Ghulam Ali will soon m...
# 55102  The Islamic State (IS) has acknowledged the de...
# 55103  UK-based oil firm Cairn Energy on Tuesday said...
#
# [55104 rows x 2 columns]

# %%
#df = pd.concat([duc, news])
#del df1, df2
df = pd.concat([duc, news], ignore_index=True, sort=False)
# Shuffling the df
df = df.sample(frac=1).reset_index(drop=True)

print(f'Dataset size: {len(df)}')
news=df
# Out:
# Dataset size: 55604

# %%
news.head()
# Out:
#                                                Short  \
# 0  About 300 US Marines were deployed in Norway o...
# 1  The ICC on Thursday removed India, England and...
# 2  The world number one women&#39;s doubles pair ...
# 3  A lawyer practising in the Delhi High Court an...
# 4  representatives of exiled east timorese pro-in...
#
#                                             Headline
# 0  US Marines stationed in Norway to train in win...
# 1     ICC removes India from permanent member status
# 2     Aus Open: Mirza-Hingis, Bopanna-Mergea advance
# 3       Delhi lawyer declares ₹125 crore black money
# 4  Indonesian troops attack unarmed E. Timor civi...

# %%
news=news.replace(r'&#45;','-', regex=True).replace(r'&#39;','`', regex=True).replace(r'&amp','&', regex=True).replace(r'&#34;','"', regex=True)
news.head()
# Out:
#                                                Short  \
# 0  About 300 US Marines were deployed in Norway o...
# 1  The ICC on Thursday removed India, England and...
# 2  The world number one women`s doubles pair of S...
# 3  A lawyer practising in the Delhi High Court an...
# 4  representatives of exiled east timorese pro-in...
#
#                                             Headline
# 0  US Marines stationed in Norway to train in win...
# 1     ICC removes India from permanent member status
# 2     Aus Open: Mirza-Hingis, Bopanna-Mergea advance
# 3       Delhi lawyer declares ₹125 crore black money
# 4  Indonesian troops attack unarmed E. Timor civi...

# %%
article = news['Short']
summary = news['Headline']

article = article.apply(lambda x: '<SOS> ' + x + ' <EOS>')
summary = summary.apply(lambda x: '<SOS> ' + x + ' <EOS>')

# %%
def preprocess(text):
    text = re.sub(r"&.[1-9]+;"," ",text)
    return text
article = article.apply(lambda x: preprocess(x))
summary = summary.apply(lambda x: preprocess(x))

# %%
article[8]
# Out:
# '<SOS> The government is likely to gain the votes it needs to pass the Goods and Services Tax (GST) Bill this year, global financial services firm Morgan Stanley has said. Currently, the number of members opposing the bill in the Rajya Sabha stands at 91 and it needs to fall to 82 for the bill to be cleared, it added. <EOS>'

# %%
print("****************************")
summary[8]
# Out:
# ****************************
# '<SOS> Govt may pass GST Bill in 2016: Morgan Stanley <EOS>'

# %%
filters = '!"#$%&()*+,-./:;=?@[\\]^_`{|}~\t\n'
oov_token = '<unk>'
article_tokenizer = tf.keras.preprocessing.text.Tokenizer(oov_token=oov_token)
summary_tokenizer = tf.keras.preprocessing.text.Tokenizer(filters=filters, oov_token=oov_token)
article_tokenizer.fit_on_texts(article)
summary_tokenizer.fit_on_texts(summary)
inputs = article_tokenizer.texts_to_sequences(article)
targets = summary_tokenizer.texts_to_sequences(summary)

# %%
ENCODER_VOCAB = len(article_tokenizer.word_index) + 1
DECODER_VOCAB = len(summary_tokenizer.word_index) + 1
print(ENCODER_VOCAB, DECODER_VOCAB)
# Out:
# 76618 29992

# %%
# Padding ensures that all sequences are of uniform length, which is crucial for training neural networks.
# Casting to int64 ensures that the data type aligns with the expected input for TensorFlow models (some layers or operations might need int64).
inputs = tf.keras.preprocessing.sequence.pad_sequences(inputs, maxlen=ENCODER_LEN, padding='post', truncating='post')
targets = tf.keras.preprocessing.sequence.pad_sequences(targets, maxlen=DECODER_LEN, padding='post', truncating='post')
inputs = tf.cast(inputs, dtype=tf.int64)
targets = tf.cast(targets, dtype=tf.int64)

# %%
dataset = tf.data.Dataset.from_tensor_slices((inputs, targets)).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

# %% [markdown]
# vanilla transformer

# %%
def get_angles(position, i, d_model):
    angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
    return position * angle_rates

def positional_encoding(position, d_model):
    angle_rads = get_angles(
        np.arange(position)[:, np.newaxis],
        np.arange(d_model)[np.newaxis, :],
        d_model
    )

    angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])

    angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])

    pos_encoding = angle_rads[np.newaxis, ...]

    return tf.cast(pos_encoding, dtype=tf.float32)

def create_padding_mask(seq):
    seq = tf.cast(tf.math.equal(seq, 0), tf.float32)
    return seq[:, tf.newaxis, tf.newaxis, :]

def create_look_ahead_mask(size):
    mask = 1 - tf.linalg.band_part(tf.ones((size, size)), -1, 0)
    return mask

def scaled_dot_product_attention(q, k, v, mask):
    matmul_qk = tf.matmul(q, k, transpose_b=True)

    dk = tf.cast(tf.shape(k)[-1], tf.float32)
    scaled_attention_logits = matmul_qk / tf.math.sqrt(dk)

    if mask is not None:
        scaled_attention_logits += (mask * -1e9)

    attention_weights = tf.nn.softmax(scaled_attention_logits, axis=-1)

    output = tf.matmul(attention_weights, v)
    return output, attention_weights

# %%
class MultiHeadAttention(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads):
        super(MultiHeadAttention, self).__init__()
        self.num_heads = num_heads
        self.d_model = d_model

        assert d_model % self.num_heads == 0

        self.depth = d_model // self.num_heads

        self.wq = tf.keras.layers.Dense(d_model)
        self.wk = tf.keras.layers.Dense(d_model)
        self.wv = tf.keras.layers.Dense(d_model)

        self.dense = tf.keras.layers.Dense(d_model)

    def split_heads(self, x, batch_size):
        x = tf.reshape(x, (batch_size, -1, self.num_heads, self.depth))
        return tf.transpose(x, perm=[0, 2, 1, 3])

    def call(self, v, k, q, mask):
        batch_size = tf.shape(q)[0]

        q = self.wq(q)
        k = self.wk(k)
        v = self.wv(v)

        q = self.split_heads(q, batch_size)
        k = self.split_heads(k, batch_size)
        v = self.split_heads(v, batch_size)

        scaled_attention, attention_weights = scaled_dot_product_attention(
            q, k, v, mask)

        scaled_attention = tf.transpose(scaled_attention, perm=[0, 2, 1, 3])

        concat_attention = tf.reshape(scaled_attention, (batch_size, -1, self.d_model))
        output = self.dense(concat_attention)

        return output, attention_weights

def point_wise_feed_forward_network(d_model, dff):
    return tf.keras.Sequential([
        tf.keras.layers.Dense(dff, activation='relu'),
        tf.keras.layers.Dense(d_model)
    ])

# %%
class EncoderLayer(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads, dff, rate=0.1):
        super(EncoderLayer, self).__init__()

        self.mha = MultiHeadAttention(d_model, num_heads)
        self.ffn = point_wise_feed_forward_network(d_model, dff)

        self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)

        self.dropout1 = tf.keras.layers.Dropout(rate)
        self.dropout2 = tf.keras.layers.Dropout(rate)

    def call(self, x, training, mask):
        attn_output, _ = self.mha(x, x, x, mask)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(x + attn_output)

        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output, training=training)
        out2 = self.layernorm2(out1 + ffn_output)

        return out2

# %%
class DecoderLayer(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads, dff, rate=0.1):
        super(DecoderLayer, self).__init__()

        self.mha1 = MultiHeadAttention(d_model, num_heads)
        self.mha2 = MultiHeadAttention(d_model, num_heads)

        self.ffn = point_wise_feed_forward_network(d_model, dff)

        self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm3 = tf.keras.layers.LayerNormalization(epsilon=1e-6)

        self.dropout1 = tf.keras.layers.Dropout(rate)
        self.dropout2 = tf.keras.layers.Dropout(rate)
        self.dropout3 = tf.keras.layers.Dropout(rate)


    def call(self, x, enc_output, training, look_ahead_mask, padding_mask):
        attn1, attn_weights_block1 = self.mha1(x, x, x, look_ahead_mask)
        attn1 = self.dropout1(attn1, training=training)
        out1 = self.layernorm1(attn1 + x)

        attn2, attn_weights_block2 = self.mha2(enc_output, enc_output, out1, padding_mask)
        attn2 = self.dropout2(attn2, training=training)
        out2 = self.layernorm2(attn2 + out1)

        ffn_output = self.ffn(out2)
        ffn_output = self.dropout3(ffn_output, training=training)
        out3 = self.layernorm3(ffn_output + out2)

        return out3, attn_weights_block1, attn_weights_block2

# %%
class Encoder(tf.keras.layers.Layer):
    def __init__(self, num_layers, d_model, num_heads, dff, input_vocab_size, maximum_position_encoding, rate=0.1):
        super(Encoder, self).__init__()

        self.d_model = d_model
        self.num_layers = num_layers

        # Embedding and positional encoding layers
        self.embedding = tf.keras.layers.Embedding(input_vocab_size, d_model)
        self.pos_encoding = positional_encoding(maximum_position_encoding, self.d_model)

        # Encoder layers (list of EncoderLayer instances)
        self.enc_layers = [EncoderLayer(d_model, num_heads, dff, rate) for _ in range(num_layers)]

        self.dropout = tf.keras.layers.Dropout(rate)

    def call(self, x, training, mask):
        seq_len = tf.shape(x)[1]

        # Apply embedding and positional encoding
        x = self.embedding(x)
        x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
        x += self.pos_encoding[:, :seq_len, :]

        x = self.dropout(x, training=training)

        # Pass through each encoder layer
        for i in range(self.num_layers):
            # Make sure mask is passed as keyword argument
            x = self.enc_layers[i](x, training=training, mask=mask)

        return x


class Decoder(tf.keras.layers.Layer):

    def __init__(self, num_layers, d_model, num_heads, dff, target_vocab_size, maximum_position_encoding, rate=0.1):
        super(Decoder, self).__init__()

        self.d_model = d_model
        self.num_layers = num_layers

        # Embedding and positional encoding layers
        self.embedding = tf.keras.layers.Embedding(target_vocab_size, d_model)
        self.pos_encoding = positional_encoding(maximum_position_encoding, d_model)

        # Decoder layers (list of DecoderLayer instances)
        self.dec_layers = [DecoderLayer(d_model, num_heads, dff, rate) for _ in range(num_layers)]
        self.dropout = tf.keras.layers.Dropout(rate)

    def call(self, x, enc_output, training, look_ahead_mask, padding_mask):
        seq_len = tf.shape(x)[1]
        attention_weights = {}

        # Apply embedding and positional encoding
        x = self.embedding(x)
        x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
        x += self.pos_encoding[:, :seq_len, :]

        x = self.dropout(x, training=training)

        # Pass through each decoder layer
        for i in range(self.num_layers):
            # Pass the look_ahead_mask and padding_mask as keyword arguments
            x, block1, block2 = self.dec_layers[i](x, enc_output, training=training, look_ahead_mask=look_ahead_mask, padding_mask=padding_mask)

            # Save the attention weights for later inspection
            attention_weights['decoder_layer{}_block1'.format(i+1)] = block1
            attention_weights['decoder_layer{}_block2'.format(i+1)] = block2

        return x, attention_weights

# %%
class Transformer(tf.keras.Model):
    def __init__(self, num_layers, d_model, num_heads, dff, input_vocab_size, target_vocab_size, pe_input, pe_target, rate=0.1):
        super(Transformer, self).__init__()

        self.encoder = Encoder(num_layers, d_model, num_heads, dff, input_vocab_size, pe_input, rate)
        self.decoder = Decoder(num_layers, d_model, num_heads, dff, target_vocab_size, pe_target, rate)
        self.final_layer = tf.keras.layers.Dense(target_vocab_size)

    def call(self, inp, tar, training, enc_padding_mask, look_ahead_mask, dec_padding_mask):
        # Pass the input through the encoder
        enc_output = self.encoder(x=inp, training=training, mask=enc_padding_mask)

        # Pass the target and encoder output through the decoder
        dec_output, attention_weights = self.decoder(
            x=tar, enc_output=enc_output, training=training,
            look_ahead_mask=look_ahead_mask, padding_mask=dec_padding_mask
        )

        # Pass the decoder output through the final linear layer
        final_output = self.final_layer(dec_output)

        return final_output, attention_weights

# %%
num_layers = 3
d_model = 128
dff = 512
num_heads = 4
dropout_rate = 0.2
EPOCHS = 30

# %% [markdown]
# custom learning rate

# %%
class CustomSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, d_model, warmup_steps=4000):
        super(CustomSchedule, self).__init__()

        self.d_model = d_model
        self.d_model = tf.cast(self.d_model, tf.float32)
        self.warmup_steps = warmup_steps

    def __call__(self, step):
        # Cast step to float32 for compatibility with tf.math.rsqrt
        step = tf.cast(step, tf.float32)
        arg1 = tf.math.rsqrt(step)
        arg2 = step * (self.warmup_steps ** -1.5)

        return tf.math.rsqrt(self.d_model) * tf.math.minimum(arg1, arg2)

# %%
learning_rate = CustomSchedule(d_model)

optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.9, beta_2=0.98, epsilon=1e-9)

# %%
temp_learning_rate_schedule = CustomSchedule(d_model)

plt.plot(temp_learning_rate_schedule(tf.range(40000, dtype=tf.float32)))
plt.ylabel("Learning Rate")
plt.xlabel("Train Step")
# Out:
# Text(0.5, 0, 'Train Step')

# %% [markdown]
# custom loss and accuracy

# %%
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction='none')
def loss_function(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)

    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask

    return tf.reduce_sum(loss_)/tf.reduce_sum(mask)


def accuracy_function(real, pred):
    accuracies = tf.equal(real, tf.argmax(pred, axis=2))
    #accuracies = tf.cast(accuracies, dtype= tf.float32)

    mask = tf.math.logical_not(tf.math.equal(real, 0))
    accuracies = tf.math.logical_and(mask, accuracies)

    accuracies = tf.cast(accuracies, dtype=tf.float32)
    mask = tf.cast(mask, dtype=tf.float32)
    return tf.reduce_sum(accuracies)/tf.reduce_sum(mask)

# %%
train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.Mean(name='train_accuracy')

# %%
transformer = Transformer(
    num_layers=num_layers,
    d_model=d_model,
    num_heads=num_heads,
    dff=dff,
    input_vocab_size=ENCODER_VOCAB,
    target_vocab_size=DECODER_VOCAB,
    pe_input=1000,
    pe_target=1000,
    rate=dropout_rate)

# %%
def create_look_ahead_mask(size):
    mask = 1 - tf.linalg.band_part(tf.ones((size, size)), -1, 0)
    return mask  # shape: (size, size)

# %%
def create_masks(inp, tar):
    enc_padding_mask = create_padding_mask(inp)  # Mask for the encoder input
    dec_padding_mask = create_padding_mask(inp)  # Mask for the encoder input used in the decoder

    # Create a look-ahead mask for the target sequence
    look_ahead_mask = create_look_ahead_mask(tf.shape(tar)[1])

    # Mask for the target sequence, combining look-ahead and padding mask
    dec_target_padding_mask = create_padding_mask(tar)
    combined_mask = tf.maximum(dec_target_padding_mask, look_ahead_mask)

    return enc_padding_mask, combined_mask, dec_padding_mask, look_ahead_mask

# %%
checkpoint_path = "checkpoints"

ckpt = tf.train.Checkpoint(transformer=transformer, optimizer=optimizer)

ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

if ckpt_manager.latest_checkpoint:
    ckpt.restore(ckpt_manager.latest_checkpoint)
    print ('Latest checkpoint restored!!')

# %%
@tf.function
def train_step(inp, tar):
    tar_inp = tar[:, :-1]
    tar_real = tar[:, 1:]

    # Generate necessary masks
    enc_padding_mask, combined_mask, dec_padding_mask, look_ahead_mask = create_masks(inp, tar_inp)

    with tf.GradientTape() as tape:
        # Pass arguments as keyword arguments
        predictions, _ = transformer(
            inp=inp,  # input sequence
            tar=tar_inp,  # target sequence
            training=True,  # specify the training mode
            enc_padding_mask=enc_padding_mask,  # encoder padding mask
            dec_padding_mask=dec_padding_mask,  # decoder padding mask
            look_ahead_mask=look_ahead_mask  # look-ahead mask
        )

        # Calculate loss
        loss = loss_function(tar_real, predictions)

    # Compute gradients and update model weights
    gradients = tape.gradient(loss, transformer.trainable_variables)
    optimizer.apply_gradients(zip(gradients, transformer.trainable_variables))

    # Update training metrics
    train_loss(loss)
    train_accuracy(accuracy_function(tar_real, predictions))

# %% [markdown]
# training the model

# %%
for epoch in range(EPOCHS):
    start = time.time()

    # Reset metrics at the start of each epoch
    train_loss.reset_state()
    train_accuracy.reset_state()

    # Loop through each batch in the dataset
    for (batch, (inp, tar)) in enumerate(dataset):
        train_step(inp, tar)  # train_step will call create_masks internally

        if batch % 100 == 0:
            # Print batch-level training loss and accuracy every 100 batches
            print(f'Epoch {epoch + 1} Batch {batch} Loss {train_loss.result():.4f} Accuracy {train_accuracy.result():.4f}')

    # Save a checkpoint every 5 epochs
    if (epoch + 1) % 5 == 0:
        ckpt_save_path = ckpt_manager.save()
        print(f'Saving checkpoint for epoch {epoch + 1} at {ckpt_save_path}')

    # Print epoch-level training loss, accuracy, and time taken
    print(f'Epoch {epoch + 1} Loss {train_loss.result():.4f} Accuracy {train_accuracy.result():.4f}')
    print(f'Time taken for 1 epoch: {time.time() - start} secs\n')
# Out:
# Epoch 1 Batch 0 Loss 10.3228 Accuracy 0.0016
# Epoch 1 Batch 100 Loss 10.2253 Accuracy 0.0551
# Epoch 1 Batch 200 Loss 10.0114 Accuracy 0.0792
# Epoch 1 Batch 300 Loss 9.7101 Accuracy 0.0872
# Epoch 1 Batch 400 Loss 9.3674 Accuracy 0.0913
# Epoch 1 Batch 500 Loss 9.0505 Accuracy 0.0937
# Epoch 1 Batch 600 Loss 8.8035 Accuracy 0.0954
# Epoch 1 Batch 700 Loss 8.6145 Accuracy 0.0989
# Epoch 1 Batch 800 Loss 8.4630 Accuracy 0.1021
# Epoch 1 Loss 8.3746 Accuracy 0.1044
# Time taken for 1 epoch: 95.18156719207764 secs
#
# Epoch 2 Batch 0 Loss 7.2479 Accuracy 0.1368
# Epoch 2 Batch 100 Loss 7.2438 Accuracy 0.1334
# Epoch 2 Batch 200 Loss 7.2081 Accuracy 0.1350
# Epoch 2 Batch 300 Loss 7.1650 Accuracy 0.1374
# Epoch 2 Batch 400 Loss 7.1161 Accuracy 0.1391
# Epoch 2 Batch 500 Loss 7.0671 Accuracy 0.1411
# Epoch 2 Batch 600 Loss 7.0159 Accuracy 0.1431
# Epoch 2 Batch 700 Loss 6.9679 Accuracy 0.1450
# Epoch 2 Batch 800 Loss 6.9235 Accuracy 0.1467
# Epoch 2 Loss 6.8931 Accuracy 0.1480
# Time taken for 1 epoch: 65.75361490249634 secs
#
# Epoch 3 Batch 0 Loss 6.4573 Accuracy 0.1664
# Epoch 3 Batch 100 Loss 6.4735 Accuracy 0.1647
# Epoch 3 Batch 200 Loss 6.4387 Accuracy 0.1658
# Epoch 3 Batch 300 Loss 6.4047 Accuracy 0.1682
# Epoch 3 Batch 400 Loss 6.3696 Accuracy 0.1704
# Epoch 3 Batch 500 Loss 6.3290 Accuracy 0.1728
# Epoch 3 Batch 600 Loss 6.2916 Accuracy 0.1753
# Epoch 3 Batch 700 Loss 6.2538 Accuracy 0.1776
# Epoch 3 Batch 800 Loss 6.2207 Accuracy 0.1796
# Epoch 3 Loss 6.1963 Accuracy 0.1812
# Time taken for 1 epoch: 65.46741223335266 secs
#
# Epoch 4 Batch 0 Loss 6.0243 Accuracy 0.1761
# Epoch 4 Batch 100 Loss 5.8681 Accuracy 0.2007
# Epoch 4 Batch 200 Loss 5.8406 Accuracy 0.2028
# Epoch 4 Batch 300 Loss 5.8144 Accuracy 0.2053
# Epoch 4 Batch 400 Loss 5.7858 Accuracy 0.2075
# Epoch 4 Batch 500 Loss 5.7539 Accuracy 0.2100
# Epoch 4 Batch 600 Loss 5.7214 Accuracy 0.2126
# Epoch 4 Batch 700 Loss 5.6899 Accuracy 0.2151
# Epoch 4 Batch 800 Loss 5.6608 Accuracy 0.2176
# Epoch 4 Loss 5.6410 Accuracy 0.2190
# Time taken for 1 epoch: 65.42380666732788 secs
#
# Epoch 5 Batch 0 Loss 5.0769 Accuracy 0.2524
# Epoch 5 Batch 100 Loss 5.3692 Accuracy 0.2384
# Epoch 5 Batch 200 Loss 5.3421 Accuracy 0.2406
# Epoch 5 Batch 300 Loss 5.3259 Accuracy 0.2425
# Epoch 5 Batch 400 Loss 5.3031 Accuracy 0.2451
# Epoch 5 Batch 500 Loss 5.2757 Accuracy 0.2477
# Epoch 5 Batch 600 Loss 5.2483 Accuracy 0.2502
# Epoch 5 Batch 700 Loss 5.2218 Accuracy 0.2528
# Epoch 5 Batch 800 Loss 5.1970 Accuracy 0.2551
# Saving checkpoint for epoch 5 at checkpoints/ckpt-1
# Epoch 5 Loss 5.1782 Accuracy 0.2568
# Time taken for 1 epoch: 66.21259021759033 secs
#
# Epoch 6 Batch 0 Loss 5.0622 Accuracy 0.2548
# Epoch 6 Batch 100 Loss 4.9390 Accuracy 0.2768
# Epoch 6 Batch 200 Loss 4.9120 Accuracy 0.2788
# Epoch 6 Batch 300 Loss 4.8903 Accuracy 0.2810
# Epoch 6 Batch 400 Loss 4.8634 Accuracy 0.2841
# Epoch 6 Batch 500 Loss 4.8305 Accuracy 0.2875
# Epoch 6 Batch 600 Loss 4.8016 Accuracy 0.2903
# Epoch 6 Batch 700 Loss 4.7746 Accuracy 0.2930
# Epoch 6 Batch 800 Loss 4.7498 Accuracy 0.2955
# Epoch 6 Loss 4.7334 Accuracy 0.2971
# Time taken for 1 epoch: 65.22650218009949 secs
#
# Epoch 7 Batch 0 Loss 4.6929 Accuracy 0.2790
# Epoch 7 Batch 100 Loss 4.5233 Accuracy 0.3170
# Epoch 7 Batch 200 Loss 4.4974 Accuracy 0.3190
# Epoch 7 Batch 300 Loss 4.4824 Accuracy 0.3205
# Epoch 7 Batch 400 Loss 4.4604 Accuracy 0.3226
# Epoch 7 Batch 500 Loss 4.4332 Accuracy 0.3253
# Epoch 7 Batch 600 Loss 4.4085 Accuracy 0.3278
# Epoch 7 Batch 700 Loss 4.3846 Accuracy 0.3308
# Epoch 7 Batch 800 Loss 4.3639 Accuracy 0.3330
# Epoch 7 Loss 4.3502 Accuracy 0.3345
# Time taken for 1 epoch: 65.29045343399048 secs
#
# Epoch 8 Batch 0 Loss 4.3801 Accuracy 0.3354
# Epoch 8 Batch 100 Loss 4.1855 Accuracy 0.3516
# Epoch 8 Batch 200 Loss 4.1660 Accuracy 0.3542
# Epoch 8 Batch 300 Loss 4.1571 Accuracy 0.3556
# Epoch 8 Batch 400 Loss 4.1368 Accuracy 0.3579
# Epoch 8 Batch 500 Loss 4.1132 Accuracy 0.3601
# Epoch 8 Batch 600 Loss 4.0915 Accuracy 0.3621
# Epoch 8 Batch 700 Loss 4.0709 Accuracy 0.3646
# Epoch 8 Batch 800 Loss 4.0544 Accuracy 0.3665
# Epoch 8 Loss 4.0441 Accuracy 0.3681
# Time taken for 1 epoch: 65.23028445243835 secs
#
# Epoch 9 Batch 0 Loss 3.8318 Accuracy 0.3868
# Epoch 9 Batch 100 Loss 3.9059 Accuracy 0.3822
# Epoch 9 Batch 200 Loss 3.8902 Accuracy 0.3843
# Epoch 9 Batch 300 Loss 3.8803 Accuracy 0.3866
# Epoch 9 Batch 400 Loss 3.8670 Accuracy 0.3885
# Epoch 9 Batch 500 Loss 3.8452 Accuracy 0.3909
# Epoch 9 Batch 600 Loss 3.8262 Accuracy 0.3930
# Epoch 9 Batch 700 Loss 3.8097 Accuracy 0.3953
# Epoch 9 Batch 800 Loss 3.7971 Accuracy 0.3972
# Epoch 9 Loss 3.7887 Accuracy 0.3981
# Time taken for 1 epoch: 65.10389375686646 secs
#
# Epoch 10 Batch 0 Loss 3.7878 Accuracy 0.3811
# Epoch 10 Batch 100 Loss 3.6757 Accuracy 0.4124
# Epoch 10 Batch 200 Loss 3.6605 Accuracy 0.4141
# Epoch 10 Batch 300 Loss 3.6579 Accuracy 0.4140
# Epoch 10 Batch 400 Loss 3.6412 Accuracy 0.4160
# Epoch 10 Batch 500 Loss 3.6219 Accuracy 0.4184
# Epoch 10 Batch 600 Loss 3.6067 Accuracy 0.4200
# Epoch 10 Batch 700 Loss 3.5917 Accuracy 0.4219
# Epoch 10 Batch 800 Loss 3.5803 Accuracy 0.4236
# Saving checkpoint for epoch 10 at checkpoints/ckpt-2
# Epoch 10 Loss 3.5730 Accuracy 0.4242
# Time taken for 1 epoch: 66.46736311912537 secs
#
# Epoch 11 Batch 0 Loss 3.5253 Accuracy 0.4313
# Epoch 11 Batch 100 Loss 3.4736 Accuracy 0.4362
# Epoch 11 Batch 200 Loss 3.4696 Accuracy 0.4359
# Epoch 11 Batch 300 Loss 3.4658 Accuracy 0.4383
# Epoch 11 Batch 400 Loss 3.4554 Accuracy 0.4397
# Epoch 11 Batch 500 Loss 3.4363 Accuracy 0.4422
# Epoch 11 Batch 600 Loss 3.4210 Accuracy 0.4440
# Epoch 11 Batch 700 Loss 3.4088 Accuracy 0.4458
# Epoch 11 Batch 800 Loss 3.3986 Accuracy 0.4473
# Epoch 11 Loss 3.3928 Accuracy 0.4480
# Time taken for 1 epoch: 65.33741784095764 secs
#
# Epoch 12 Batch 0 Loss 3.4253 Accuracy 0.4444
# Epoch 12 Batch 100 Loss 3.3236 Accuracy 0.4593
# Epoch 12 Batch 200 Loss 3.3213 Accuracy 0.4586
# Epoch 12 Batch 300 Loss 3.3184 Accuracy 0.4600
# Epoch 12 Batch 400 Loss 3.3064 Accuracy 0.4618
# Epoch 12 Batch 500 Loss 3.2886 Accuracy 0.4636
# Epoch 12 Batch 600 Loss 3.2782 Accuracy 0.4650
# Epoch 12 Batch 700 Loss 3.2696 Accuracy 0.4666
# Epoch 12 Batch 800 Loss 3.2607 Accuracy 0.4681
# Epoch 12 Loss 3.2560 Accuracy 0.4689
# Time taken for 1 epoch: 65.14915823936462 secs
#
# Epoch 13 Batch 0 Loss 3.4140 Accuracy 0.4561
# Epoch 13 Batch 100 Loss 3.2061 Accuracy 0.4771
# Epoch 13 Batch 200 Loss 3.2035 Accuracy 0.4782
# Epoch 13 Batch 300 Loss 3.1989 Accuracy 0.4787
# Epoch 13 Batch 400 Loss 3.1882 Accuracy 0.4804
# Epoch 13 Batch 500 Loss 3.1736 Accuracy 0.4819
# Epoch 13 Batch 600 Loss 3.1606 Accuracy 0.4831
# Epoch 13 Batch 700 Loss 3.1513 Accuracy 0.4849
# Epoch 13 Batch 800 Loss 3.1419 Accuracy 0.4859
# Epoch 13 Loss 3.1367 Accuracy 0.4867
# Time taken for 1 epoch: 65.15834307670593 secs
#
# Epoch 14 Batch 0 Loss 3.3477 Accuracy 0.4553
# Epoch 14 Batch 100 Loss 3.0793 Accuracy 0.4961
# Epoch 14 Batch 200 Loss 3.0724 Accuracy 0.4961
# Epoch 14 Batch 300 Loss 3.0743 Accuracy 0.4967
# Epoch 14 Batch 400 Loss 3.0661 Accuracy 0.4979
# Epoch 14 Batch 500 Loss 3.0485 Accuracy 0.4998
# Epoch 14 Batch 600 Loss 3.0376 Accuracy 0.5007
# Epoch 14 Batch 700 Loss 3.0281 Accuracy 0.5022
# Epoch 14 Batch 800 Loss 3.0179 Accuracy 0.5033
# Epoch 14 Loss 3.0142 Accuracy 0.5036
# Time taken for 1 epoch: 65.15739440917969 secs
#
# Epoch 15 Batch 0 Loss 3.1431 Accuracy 0.5081
# Epoch 15 Batch 100 Loss 2.9525 Accuracy 0.5110
# Epoch 15 Batch 200 Loss 2.9550 Accuracy 0.5105
# Epoch 15 Batch 300 Loss 2.9505 Accuracy 0.5130
# Epoch 15 Batch 400 Loss 2.9405 Accuracy 0.5141
# Epoch 15 Batch 500 Loss 2.9237 Accuracy 0.5161
# Epoch 15 Batch 600 Loss 2.9118 Accuracy 0.5172
# Epoch 15 Batch 700 Loss 2.9015 Accuracy 0.5184
# Epoch 15 Batch 800 Loss 2.8952 Accuracy 0.5196
# Saving checkpoint for epoch 15 at checkpoints/ckpt-3
# Epoch 15 Loss 2.8910 Accuracy 0.5201
# Time taken for 1 epoch: 66.08833742141724 secs
#
# Epoch 16 Batch 0 Loss 2.9443 Accuracy 0.5089
# Epoch 16 Batch 100 Loss 2.8350 Accuracy 0.5260
# Epoch 16 Batch 200 Loss 2.8273 Accuracy 0.5269
# Epoch 16 Batch 300 Loss 2.8254 Accuracy 0.5277
# Epoch 16 Batch 400 Loss 2.8194 Accuracy 0.5288
# Epoch 16 Batch 500 Loss 2.8020 Accuracy 0.5310
# Epoch 16 Batch 600 Loss 2.7918 Accuracy 0.5318
# Epoch 16 Batch 700 Loss 2.7839 Accuracy 0.5332
# Epoch 16 Batch 800 Loss 2.7765 Accuracy 0.5344
# Epoch 16 Loss 2.7729 Accuracy 0.5347
# Time taken for 1 epoch: 65.21300482749939 secs
#
# Epoch 17 Batch 0 Loss 2.6120 Accuracy 0.5728
# Epoch 17 Batch 100 Loss 2.7212 Accuracy 0.5410
# Epoch 17 Batch 200 Loss 2.7092 Accuracy 0.5419
# Epoch 17 Batch 300 Loss 2.7103 Accuracy 0.5426
# Epoch 17 Batch 400 Loss 2.7010 Accuracy 0.5442
# Epoch 17 Batch 500 Loss 2.6887 Accuracy 0.5455
# Epoch 17 Batch 600 Loss 2.6782 Accuracy 0.5465
# Epoch 17 Batch 700 Loss 2.6700 Accuracy 0.5479
# Epoch 17 Batch 800 Loss 2.6606 Accuracy 0.5494
# Epoch 17 Loss 2.6571 Accuracy 0.5496
# Time taken for 1 epoch: 65.15333080291748 secs
#
# Epoch 18 Batch 0 Loss 2.5969 Accuracy 0.5391
# Epoch 18 Batch 100 Loss 2.6030 Accuracy 0.5546
# Epoch 18 Batch 200 Loss 2.5965 Accuracy 0.5559
# Epoch 18 Batch 300 Loss 2.6038 Accuracy 0.5562
# Epoch 18 Batch 400 Loss 2.5952 Accuracy 0.5581
# Epoch 18 Batch 500 Loss 2.5834 Accuracy 0.5592
# Epoch 18 Batch 600 Loss 2.5748 Accuracy 0.5602
# Epoch 18 Batch 700 Loss 2.5663 Accuracy 0.5612
# Epoch 18 Batch 800 Loss 2.5601 Accuracy 0.5620
# Epoch 18 Loss 2.5580 Accuracy 0.5622
# Time taken for 1 epoch: 65.2585506439209 secs
#
# Epoch 19 Batch 0 Loss 2.7346 Accuracy 0.5547
# Epoch 19 Batch 100 Loss 2.5219 Accuracy 0.5664
# Epoch 19 Batch 200 Loss 2.5063 Accuracy 0.5675
# Epoch 19 Batch 300 Loss 2.5079 Accuracy 0.5679
# Epoch 19 Batch 400 Loss 2.4998 Accuracy 0.5695
# Epoch 19 Batch 500 Loss 2.4901 Accuracy 0.5713
# Epoch 19 Batch 600 Loss 2.4831 Accuracy 0.5720
# Epoch 19 Batch 700 Loss 2.4744 Accuracy 0.5733
# Epoch 19 Batch 800 Loss 2.4669 Accuracy 0.5744
# Epoch 19 Loss 2.4646 Accuracy 0.5746
# Time taken for 1 epoch: 65.15755295753479 secs
#
# Epoch 20 Batch 0 Loss 2.4219 Accuracy 0.5855
# Epoch 20 Batch 100 Loss 2.4290 Accuracy 0.5802
# Epoch 20 Batch 200 Loss 2.4220 Accuracy 0.5801
# Epoch 20 Batch 300 Loss 2.4235 Accuracy 0.5808
# Epoch 20 Batch 400 Loss 2.4178 Accuracy 0.5825
# Epoch 20 Batch 500 Loss 2.4063 Accuracy 0.5837
# Epoch 20 Batch 600 Loss 2.3977 Accuracy 0.5846
# Epoch 20 Batch 700 Loss 2.3906 Accuracy 0.5857
# Epoch 20 Batch 800 Loss 2.3841 Accuracy 0.5866
# Saving checkpoint for epoch 20 at checkpoints/ckpt-4
# Epoch 20 Loss 2.3805 Accuracy 0.5872
# Time taken for 1 epoch: 66.45644879341125 secs
#
# Epoch 21 Batch 0 Loss 2.3493 Accuracy 0.6056
# Epoch 21 Batch 100 Loss 2.3476 Accuracy 0.5913
# Epoch 21 Batch 200 Loss 2.3436 Accuracy 0.5914
# Epoch 21 Batch 300 Loss 2.3445 Accuracy 0.5923
# Epoch 21 Batch 400 Loss 2.3387 Accuracy 0.5940
# Epoch 21 Batch 500 Loss 2.3298 Accuracy 0.5952
# Epoch 21 Batch 600 Loss 2.3218 Accuracy 0.5957
# Epoch 21 Batch 700 Loss 2.3157 Accuracy 0.5966
# Epoch 21 Batch 800 Loss 2.3103 Accuracy 0.5973
# Epoch 21 Loss 2.3070 Accuracy 0.5976
# Time taken for 1 epoch: 65.2011935710907 secs
#
# Epoch 22 Batch 0 Loss 2.2779 Accuracy 0.6032
# Epoch 22 Batch 100 Loss 2.2772 Accuracy 0.6029
# Epoch 22 Batch 200 Loss 2.2684 Accuracy 0.6039
# Epoch 22 Batch 300 Loss 2.2766 Accuracy 0.6033
# Epoch 22 Batch 400 Loss 2.2712 Accuracy 0.6044
# Epoch 22 Batch 500 Loss 2.2612 Accuracy 0.6055
# Epoch 22 Batch 600 Loss 2.2542 Accuracy 0.6059
# Epoch 22 Batch 700 Loss 2.2474 Accuracy 0.6069
# Epoch 22 Batch 800 Loss 2.2402 Accuracy 0.6080
# Epoch 22 Loss 2.2391 Accuracy 0.6079
# Time taken for 1 epoch: 64.73004078865051 secs
#
# Epoch 23 Batch 0 Loss 2.1778 Accuracy 0.6356
# Epoch 23 Batch 100 Loss 2.2202 Accuracy 0.6104
# Epoch 23 Batch 200 Loss 2.2112 Accuracy 0.6113
# Epoch 23 Batch 300 Loss 2.2148 Accuracy 0.6114
# Epoch 23 Batch 400 Loss 2.2117 Accuracy 0.6121
# Epoch 23 Batch 500 Loss 2.2019 Accuracy 0.6133
# Epoch 23 Batch 600 Loss 2.1950 Accuracy 0.6142
# Epoch 23 Batch 700 Loss 2.1879 Accuracy 0.6154
# Epoch 23 Batch 800 Loss 2.1824 Accuracy 0.6162
# Epoch 23 Loss 2.1806 Accuracy 0.6166
# Time taken for 1 epoch: 65.09566473960876 secs
#
# Epoch 24 Batch 0 Loss 2.4362 Accuracy 0.5651
# Epoch 24 Batch 100 Loss 2.1539 Accuracy 0.6199
# Epoch 24 Batch 200 Loss 2.1502 Accuracy 0.6208
# Epoch 24 Batch 300 Loss 2.1563 Accuracy 0.6205
# Epoch 24 Batch 400 Loss 2.1524 Accuracy 0.6219
# Epoch 24 Batch 500 Loss 2.1425 Accuracy 0.6236
# Epoch 24 Batch 600 Loss 2.1369 Accuracy 0.6241
# Epoch 24 Batch 700 Loss 2.1304 Accuracy 0.6254
# Epoch 24 Batch 800 Loss 2.1245 Accuracy 0.6263
# Epoch 24 Loss 2.1225 Accuracy 0.6265
# Time taken for 1 epoch: 64.96948552131653 secs
#
# Epoch 25 Batch 0 Loss 2.2644 Accuracy 0.6142
# Epoch 25 Batch 100 Loss 2.0984 Accuracy 0.6254
# Epoch 25 Batch 200 Loss 2.0966 Accuracy 0.6274
# Epoch 25 Batch 300 Loss 2.0990 Accuracy 0.6286
# Epoch 25 Batch 400 Loss 2.0965 Accuracy 0.6296
# Epoch 25 Batch 500 Loss 2.0889 Accuracy 0.6306
# Epoch 25 Batch 600 Loss 2.0806 Accuracy 0.6318
# Epoch 25 Batch 700 Loss 2.0757 Accuracy 0.6326
# Epoch 25 Batch 800 Loss 2.0702 Accuracy 0.6336
# Saving checkpoint for epoch 25 at checkpoints/ckpt-5
# Epoch 25 Loss 2.0683 Accuracy 0.6339
# Time taken for 1 epoch: 65.9799234867096 secs
#
# Epoch 26 Batch 0 Loss 2.0071 Accuracy 0.6316
# Epoch 26 Batch 100 Loss 2.0426 Accuracy 0.6373
# Epoch 26 Batch 200 Loss 2.0490 Accuracy 0.6365
# Epoch 26 Batch 300 Loss 2.0479 Accuracy 0.6366
# Epoch 26 Batch 400 Loss 2.0443 Accuracy 0.6382
# Epoch 26 Batch 500 Loss 2.0357 Accuracy 0.6393
# Epoch 26 Batch 600 Loss 2.0293 Accuracy 0.6404
# Epoch 26 Batch 700 Loss 2.0238 Accuracy 0.6416
# Epoch 26 Batch 800 Loss 2.0186 Accuracy 0.6424
# Epoch 26 Loss 2.0176 Accuracy 0.6425
# Time taken for 1 epoch: 65.19215559959412 secs
#
# Epoch 27 Batch 0 Loss 1.9475 Accuracy 0.6342
# Epoch 27 Batch 100 Loss 1.9959 Accuracy 0.6457
# Epoch 27 Batch 200 Loss 1.9864 Accuracy 0.6473
# Epoch 27 Batch 300 Loss 1.9959 Accuracy 0.6465
# Epoch 27 Batch 400 Loss 1.9957 Accuracy 0.6468
# Epoch 27 Batch 500 Loss 1.9865 Accuracy 0.6475
# Epoch 27 Batch 600 Loss 1.9806 Accuracy 0.6486
# Epoch 27 Batch 700 Loss 1.9764 Accuracy 0.6496
# Epoch 27 Batch 800 Loss 1.9722 Accuracy 0.6502
# Epoch 27 Loss 1.9708 Accuracy 0.6504
# Time taken for 1 epoch: 65.15858173370361 secs
#
# Epoch 28 Batch 0 Loss 1.9160 Accuracy 0.6574
# Epoch 28 Batch 100 Loss 1.9654 Accuracy 0.6503
# Epoch 28 Batch 200 Loss 1.9534 Accuracy 0.6516
# Epoch 28 Batch 300 Loss 1.9583 Accuracy 0.6522
# Epoch 28 Batch 400 Loss 1.9528 Accuracy 0.6530
# Epoch 28 Batch 500 Loss 1.9447 Accuracy 0.6538
# Epoch 28 Batch 600 Loss 1.9386 Accuracy 0.6544
# Epoch 28 Batch 700 Loss 1.9338 Accuracy 0.6555
# Epoch 28 Batch 800 Loss 1.9298 Accuracy 0.6563
# Epoch 28 Loss 1.9288 Accuracy 0.6563
# Time taken for 1 epoch: 65.09590721130371 secs
#
# Epoch 29 Batch 0 Loss 1.9296 Accuracy 0.6568
# Epoch 29 Batch 100 Loss 1.9136 Accuracy 0.6580
# Epoch 29 Batch 200 Loss 1.9110 Accuracy 0.6589
# Epoch 29 Batch 300 Loss 1.9135 Accuracy 0.6592
# Epoch 29 Batch 400 Loss 1.9096 Accuracy 0.6603
# Epoch 29 Batch 500 Loss 1.9020 Accuracy 0.6616
# Epoch 29 Batch 600 Loss 1.8954 Accuracy 0.6622
# Epoch 29 Batch 700 Loss 1.8924 Accuracy 0.6629
# Epoch 29 Batch 800 Loss 1.8887 Accuracy 0.6634
# Epoch 29 Loss 1.8883 Accuracy 0.6636
# Time taken for 1 epoch: 65.22903394699097 secs
#
# Epoch 30 Batch 0 Loss 1.8163 Accuracy 0.6683
# Epoch 30 Batch 100 Loss 1.8646 Accuracy 0.6646
# Epoch 30 Batch 200 Loss 1.8734 Accuracy 0.6643
# Epoch 30 Batch 300 Loss 1.8746 Accuracy 0.6649
# Epoch 30 Batch 400 Loss 1.8722 Accuracy 0.6654
# Epoch 30 Batch 500 Loss 1.8643 Accuracy 0.6667
# Epoch 30 Batch 600 Loss 1.8585 Accuracy 0.6674
# Epoch 30 Batch 700 Loss 1.8540 Accuracy 0.6684
# Epoch 30 Batch 800 Loss 1.8506 Accuracy 0.6692
# Saving checkpoint for epoch 30 at checkpoints/ckpt-6
# Epoch 30 Loss 1.8509 Accuracy 0.6692
# Time taken for 1 epoch: 66.17009997367859 secs

# %% [markdown]
# evaluation

# %%
def evaluate(input_article):
    input_article = article_tokenizer.texts_to_sequences([input_article])
    input_article = tf.keras.preprocessing.sequence.pad_sequences(input_article, maxlen=ENCODER_LEN,
                                                                   padding='post', truncating='post')

    encoder_input = tf.expand_dims(input_article[0], 0)

    decoder_input = [summary_tokenizer.word_index['<sos>']]
    output = tf.expand_dims(decoder_input, 0)

    for i in range(DECODER_LEN):
        enc_padding_mask, combined_mask, dec_padding_mask, look_ahead_mask = create_masks(encoder_input, output)

        # Call transformer without combined_mask if it's not expected
        predictions, attention_weights = transformer(
            encoder_input,
            output,
            training=False,  # Fix: passed as keyword argument
            enc_padding_mask=enc_padding_mask,
            dec_padding_mask=dec_padding_mask,
            look_ahead_mask=look_ahead_mask  # If combined_mask is not needed, leave it out
        )

        predictions = predictions[:, -1:, :]
        predicted_id = tf.cast(tf.argmax(predictions, axis=-1), tf.int32)

        if predicted_id == summary_tokenizer.word_index['<eos>']:
            return tf.squeeze(output, axis=0), attention_weights

        output = tf.concat([output, predicted_id], axis=-1)

    return tf.squeeze(output, axis=0), attention_weights

# %%
def summarize(input_article):
    input_article=preprocess(input_article)
    summarized = evaluate(input_article=input_article)[0].numpy()
    summarized = np.expand_dims(summarized[1:], 0)
    return summary_tokenizer.sequences_to_texts(summarized)[0]

# %% [markdown]
# predictions

# %%
article[6]
# Out:
# '<SOS> India A batsman Shreyas Iyer has said he was sledged by Australian wicketkeeper Matthew Wade and David Warner on the second day of the ongoing practice match. "They started to sledge and said `this guy does not have defence, he can play only attacking shots`," said Iyer. "I am used to this type of sledging," the batsman added. <EOS>'

# %%
print("Real Headline : ", summary[6][5:-5],"\n Predicted Summary : ", summarize(article[6]))
# Out:
# Real Headline :   Aussie players sledged me during warm-up game: Shreyas Iyer
#  Predicted Summary :  aussie players mascot games due to shoulder fracture

# %%
article[16]
# Out:
# '<SOS> Smoking cannabis may double the risk of stress cardiomyopathy, a rare condition that temporarily weakens the heart, a US-based research has shown. The condition mimics the symptoms of cardiac arrest. Cannabis users experiencing an episode of stress cardiomyopathy are significantly more likely than non-users to go into cardiac arrest or need correction to abnormal heart rhythms, the study revealed. <EOS>'

# %%
print("Real Headline : ", summary[16][5:-5],"\nPredicted Summary : ", summarize(article[16]))
# Out:
# Real Headline :   Cannabis smoking may double `rare heart condition risk`
# Predicted Summary :  cannabis smoking may double rare heart condition risk

# %%
article[23]
# Out:
# '<SOS> Ratan Tata, Tata Sons interim Chairman, has reportedly written a letter to employees reassuring them about the future of the group and its companies. Further, he said that the decision to change the leadership at Tata Sons was a well-deliberated one taken to maintain the Tata culture. The letter comes a week after Tata chairman Cyrus Mistry was sacked. <EOS>'

# %%
print("Real Headline : ", summary[23][5:-5],"\nPredicted Summary : ", summarize(article[23]))
# Out:
# Real Headline :   Tata writes to employees reassuring them of group`s future
# Predicted Summary :  ratan tata writes to employees report

# %%
print("Real Headline : ", summary[0][5:-5],"\nPredicted Summary : ", summarize(article[0]))
# Out:
# Real Headline :   US Marines stationed in Norway to train in winter warfare
# Predicted Summary :  us refuses to train chinese province to train in winter

# %%
print("Real Headline : ", summary[23][5:-5],"\nPredicted Summary : ", summarize(article[23]))
# Out:
# Real Headline :   Tata writes to employees reassuring them of group`s future
# Predicted Summary :  ratan tata writes to employees report

# %%
summarize("Text Summarization - as the name suggests - involves generating short summaries of text data, in a few words or sentences. A good example of this in day-to-day life is the Inshorts news summary app, which generates summaries upto max of ~ 60 words.")
# Out:
# 'the member is the pooh story in the life'

# %%
summarize("""Cambodian leader Hun Sen on Friday rejected opposition parties' demands
for talks outside the country, accusing them of trying to ``internationalize''
the political crisis. Government and opposition parties have asked
King Norodom Sihanouk to host a summit meeting after a series of post-election
negotiations between the two opposition groups and Hun Sen's party
to form a new government failed. Opposition leaders Prince Norodom
Ranariddh and Sam Rainsy, citing Hun Sen's threats to arrest opposition
figures after two alleged attempts on his life, said they could not
negotiate freely in Cambodia and called for talks at Sihanouk's residence
in Beijing. Hun Sen, however, rejected that. ``I would like to make
it clear that all meetings related to Cambodian affairs must be conducted
in the Kingdom of Cambodia,'' Hun Sen told reporters after a Cabinet
meeting on Friday. ``No-one should internationalize Cambodian affairs.
It is detrimental to the sovereignty of Cambodia,'' he said. Hun Sen's
Cambodian People's Party won 64 of the 122 parliamentary seats in
July's elections, short of the two-thirds majority needed to form
a government on its own. Ranariddh and Sam Rainsy have charged that
Hun Sen's victory in the elections was achieved through widespread
fraud. They have demanded a thorough investigation into their election
complaints as a precondition for their cooperation in getting the
national assembly moving and a new government formed. Hun Sen said
on Friday that the opposition concerns over their safety in the country
was ``just an excuse for them to stay abroad.'' Both Ranariddh and
Sam Rainsy have been outside the country since parliament was ceremonially
opened on Sep. 24. Sam Rainsy and a number of opposition figures have
been under court investigation for a grenade attack on Hun Sen's Phnom
Penh residence on Sep. 7. Hun Sen was not home at the time of the
attack, which was followed by a police crackdown on demonstrators
contesting Hun Sen's election victory. The Sam Rainsy Party, in a
statement released Friday, accused Hun Sen of being ``unwilling to
make any compromise'' on negotiations to break the deadlock. ``A meeting
outside Cambodia, as suggested by the opposition, could place all
parties on more equal footing,'' said the statement. ``But the ruling
party refuses to negotiate unless it is able to threaten its negotiating
partners with arrest or worse.'' """)
# Out:
# 'cambodian opposition leader rejects alliance with decision'

# %%
summarize("cambodian leader hun sen on friday rejected opposition parties ' demands for talks outside the country , accusing them of trying to `` internationalize '' the political crisis .")
# Out:
# 'cambodian leader demands opposition demands opposition demands'

# %%
summarize("king norodom sihanouk has declined requests to chair a summit of cambodia 's top political leaders , saying the meeting would not bring any progress in deadlocked negotiations to form a government .")
# Out:
# "italy's premier to not seek work to bring chair says cambodia"

# %%
summarize("sometime in the summer of 1997 , an operative for osama bin laden sat down at his personal computer in a hideaway in kenya , he was worried , he wrote in an angry dispatch , about the security of the `` east africa network '' of bin laden , the saudi exile accused of masterminding a worldwide terrorist conspiracy against americans .")
# Out:
# 'osama bin laden s and osama bin laden in africa'

# %%
summarize("six months after president clinton traveled to beijing and challenged china 's leaders to move rapidly toward political reform , the administration 's policy of engaging beijing was called into question monday when chinese courts sentenced three of the nation 's most prominent dissidents to long jail sentences .")
# Out:
# 'clinton backs beijing policy for political gimmick founder'

# %%
summarize("fbi agents this week began questioning relatives of the victims of the aug. 7 u.s. embassy bombing as well as the seriously injured on request of the u.s. attorney 's office for the southern district of new york , a u.s. official said thursday .")
# Out:
# 'fbi questions u s rights victims to support victims of u s embassy'

# %%
summarize("Saurav Kant, an alumnus of upGrad and IIIT-B's PG Program in Machine learning and Artificial Intelligence, was a Sr Systems Engineer at Infosys with almost 5 years of work experience. The program and upGrad's 360-degree career support helped him transition to a Data Scientist at Tech Mahindra with 90% salary hike. upGrad's Online Power Learning has powered 3 lakh+ careers.")
# Out:
# '11 yrs since university of artificial intelligence'

# %%
summarize("Actor Ranbir Kapoor worked as an assistant director for Sanjay Leela Bhansali&#39;s &#39;Black&#39; in 2005. He is also known to have assisted in the making of the 1996 film &#39;PremGranth&#39; and his father Rishi Kapoor&#39;s directorial debut &#39;Aa Ab Laut Chalen&#39; in 1999. The actor, who has won five Filmfare awards including Best Actor for &#39;Barfi!&#39;, turned 34 on Wednesday.")
# Out:
# 'ranbir kapoor worked as assistant director for black'

# %%
print("Real Headline : ", summary[0][5:-5],"\nPredicted Summary : ", summarize(article[0]))
# Out:
# Real Headline :   US Marines stationed in Norway to train in winter warfare
# Predicted Summary :  us refuses to train chinese province to train in winter

# %%
summarize("The CBI on Saturday booked four former officials of Syndicate Bank and six others for cheating, forgery, criminal conspiracy and causing ₹209 crore loss to the state-run bank. The accused had availed home loans and credit from Syndicate Bank on the basis of forged and fabricated documents. These funds were fraudulently transferred to the companies owned by the accused persons.")
# Out:
# '4 ex bank officials booked for cheating bank of cheating bank'
